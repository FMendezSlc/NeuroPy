# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg

# %%
spec_pool =pd.read_csv('/Users/labc02/Documents/PDCB_data/MK-project/LFP_data/A32/Periodograms/Spectral_pool.csv')

# %%
spec_pool.groupby(['Genotype', 'Condition', 'Site', 'Tx'])['Date'].count()
# Out:
# Genotype  Condition  Site    Tx
# KO        Basal      CA1_p   Pl      6
#                              Tx05    6
#                      CA1_r   Pl      6
#                              Tx05    6
#                      CA3_p   Pl      6
#                              Tx05    6
#                      CA3_r   Pl      6
#                              Tx05    6
#                      DG      Pl      6
#                              Tx05    6
#                      DG_mol  Pl      6
#                              Tx05    6
#           Pinch      CA1_p   Pl      6
#                              Tx05    6
#                      CA1_r   Pl      6
#                              Tx05    6
#                      CA3_p   Pl      6
#                              Tx05    6
#                      CA3_r   Pl      6
#                              Tx05    6
#                      DG      Pl      6
#                              Tx05    6
#                      DG_mol  Pl      6
# ...

# %%
spec_abs = spec_pool[['Date', 'Genotype', 'Sex', 'Tx', 'Condition', 'Site', 'total_pw',
       'delta_abs', 'theta_abs', 'gamma_slow_abs', 'gamma_fast_abs']]

# %%
melt_abs = pd.melt(frame = spec_abs, id_vars= ['Date', 'Genotype', 'Sex', 'Tx', 'Condition', 'Site'], value_vars = ['total_pw',
       'delta_abs', 'theta_abs', 'gamma_slow_abs', 'gamma_fast_abs'], var_name = 'band', value_name = 'power')

# %%
WT_basal = melt_abs[(melt_abs['Genotype'] == 'WT') &(melt_abs['Condition']=='Basal')].copy()
WT_pinch = melt_abs[(melt_abs['Genotype'] == 'WT') &(melt_abs['Condition']=='Pinch')].copy()

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.subplot(321)
sns.boxplot(data = WT_basal[WT_basal['Site']== 'DG'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)
plt.yscale('log')
ax1.set_title('DG')
ax2 = plt.subplot(322)
sns.boxplot(data = WT_basal[WT_basal['Site']== 'DG_mol'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)
ax2.set_title('DGmol')
plt.yscale('log')

ax3 = plt.subplot(323)
sns.boxplot(data = WT_basal[WT_basal['Site']== 'CA3_p'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax3)
plt.yscale('log')
ax3.set_title('CA3p')
ax4 = plt.subplot(324)
sns.boxplot(data = WT_basal[WT_basal['Site']== 'CA3_r'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax4)
ax4.set_title('CA3r')
plt.yscale('log')

ax5 = plt.subplot(325)
sns.boxplot(data = WT_basal[WT_basal['Site']== 'CA1_p'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax5)
plt.yscale('log')
ax5.set_title('CA1p')
ax6 = plt.subplot(326)
sns.boxplot(data = WT_basal[WT_basal['Site']== 'CA1_r'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax6)
ax6.set_title('CA1r')
plt.yscale('log')

plt.tight_layout()

# %% [markdown]
# ## Absolute Basal only WT

# %%
spec_rel = spec_pool[['Date', 'Genotype', 'Sex', 'Tx', 'Condition', 'Site', 'delta_rel', 'theta_rel', 'gamma_slow_rel', 'gamma_fast_rel']]

# %%
melt_rel = pd.melt(frame = spec_rel, id_vars= ['Date', 'Genotype', 'Sex', 'Tx', 'Condition', 'Site'], value_vars = ['delta_rel', 'theta_rel', 'gamma_slow_rel', 'gamma_fast_rel'], var_name = 'band', value_name = 'power')

WTr_basal = melt_rel[(melt_rel['Genotype'] == 'WT') &(melt_rel['Condition']=='Basal')].copy()
WTr_pinch = melt_rel[(melt_rel['Genotype'] == 'WT') &(melt_rel['Condition']=='Pinch')].copy()

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.subplot(321)
sns.boxplot(data = WTr_basal[WTr_basal['Site']== 'DG'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)

ax1.set_title('DG')
ax2 = plt.subplot(322)
sns.boxplot(data = WTr_basal[WTr_basal['Site']== 'DG_mol'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)
ax2.set_title('DGmol')

ax3 = plt.subplot(323)
sns.boxplot(data = WTr_basal[WTr_basal['Site']== 'CA3_p'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax3)

ax3.set_title('CA3p')
ax4 = plt.subplot(324)
sns.boxplot(data = WTr_basal[WTr_basal['Site']== 'CA3_r'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax4)
ax4.set_title('CA3r')

ax5 = plt.subplot(325)
sns.boxplot(data = WTr_basal[WTr_basal['Site']== 'CA1_p'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax5)

ax5.set_title('CA1p')
ax6 = plt.subplot(326)
sns.boxplot(data = WTr_basal[WTr_basal['Site']== 'CA1_r'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax6)
ax6.set_title('CA1r')

plt.tight_layout()

# %% [markdown]
# ## Relative WT basal not Delta

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.subplot(321)
sns.boxplot(data = WT_pinch[WT_pinch['Site']== 'DG'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)
plt.yscale('log')
ax1.set_title('DG')
ax2 = plt.subplot(322)
sns.boxplot(data = WT_pinch[WT_pinch['Site']== 'DG_mol'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)
ax2.set_title('DGmol')
plt.yscale('log')

ax3 = plt.subplot(323)
sns.boxplot(data = WT_pinch[WT_pinch['Site']== 'CA3_p'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax3)
plt.yscale('log')
ax3.set_title('CA3p')
ax4 = plt.subplot(324)
sns.boxplot(data = WT_pinch[WT_pinch['Site']== 'CA3_r'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax4)
ax4.set_title('CA3r')
plt.yscale('log')

ax5 = plt.subplot(325)
sns.boxplot(data = WT_pinch[WT_pinch['Site']== 'CA1_p'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax5)
plt.yscale('log')
ax5.set_title('CA1p')
ax6 = plt.subplot(326)
sns.boxplot(data = WT_pinch[WT_pinch['Site']== 'CA1_r'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax6)
ax6.set_title('CA1r')
plt.yscale('log')

plt.tight_layout()

# %% [markdown]
# ## Absolute WT Pinch

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.subplot(321)
sns.boxplot(data = WTr_pinch[WTr_pinch['Site']== 'DG'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)

ax1.set_title('DG')
ax2 = plt.subplot(322)
sns.boxplot(data = WTr_pinch[WTr_pinch['Site']== 'DG_mol'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)
ax2.set_title('DGmol')

ax3 = plt.subplot(323)
sns.boxplot(data = WTr_pinch[WTr_pinch['Site']== 'CA3_p'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax3)

ax3.set_title('CA3p')
ax4 = plt.subplot(324)
sns.boxplot(data = WTr_pinch[WTr_pinch['Site']== 'CA3_r'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax4)
ax4.set_title('CA3r')

ax5 = plt.subplot(325)
sns.boxplot(data = WTr_pinch[WTr_pinch['Site']== 'CA1_p'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax5)

ax5.set_title('CA1p')
ax6 = plt.subplot(326)
sns.boxplot(data = WTr_pinch[WTr_pinch['Site']== 'CA1_r'], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax6)
ax6.set_title('CA1r')

plt.tight_layout()

# %% [markdown]
# ## Relative WT Pinch

# %% [markdown]
# # Coherence

# %%
coh_pool = pd.read_csv('/Users/labc02/Documents/PDCB_data/MK-project/LFP_data/A32/Correolograms/Coherence_pool.csv')

# %%
coh_pool.columns
# Out:
# Index(['Date', 'Genotype', 'Sex', 'Tx', 'Condition', 'Site', 'theta_coh',
#        'phase_lag'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(121)
sns.boxplot(data = coh_pool[(coh_pool['Genotype']=='WT') & (coh_pool['Condition']== 'Basal')], x = 'Site', y = 'theta_coh', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)
ax2 = plt.subplot(122)
sns.boxplot(data = coh_pool[(coh_pool['Genotype']=='WT') & (coh_pool['Condition']== 'Basal')], x = 'Site', y = 'phase_lag', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)

# %%
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(121)
sns.boxplot(data = coh_pool[(coh_pool['Genotype']=='WT') & (coh_pool['Condition']== 'Pinch')], x = 'Site', y = 'theta_coh', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)
ax2 = plt.subplot(122)
sns.boxplot(data = coh_pool[(coh_pool['Genotype']=='WT') & (coh_pool['Condition']== 'Pinch')], x = 'Site', y = 'phase_lag', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)

# %%
coh_diff = coh_pool.copy()

# %%
coh_bs = coh_diff[coh_diff['Condition']== 'Basal']
coh_p = coh_diff[coh_diff['Condition'] == 'Pinch']

# %%
coh_bs['Pinch'] = coh_p['theta_coh'].values
# Out:
# <ipython-input-226-a5775a3c7bfb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coh_bs['Pinch'] = coh_p['theta_coh'].values

# %%
coh_bs['Diff'] = coh_bs['Pinch'] - coh_bs['theta_coh']
# Out:
# <ipython-input-227-0b0c685f8778>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coh_bs['Diff'] = coh_bs['Pinch'] - coh_bs['theta_coh']

# %%
coh_bs
# Out:
#        Date Genotype  Sex    Tx Condition    Site  theta_coh  phase_lag  \
# 0    271021       WT  Fem   Tx1     Basal      DG   0.251207   1.961989
# 2    271021       WT  Fem   Tx1     Basal  DG_mol   0.299593   0.646919
# 4    271021       WT  Fem   Tx1     Basal   CA3_p   1.000000   0.000000
# 6    271021       WT  Fem   Tx1     Basal   CA3_r   0.888157   0.110572
# 8    271021       WT  Fem   Tx1     Basal   CA1_p   0.220640  -1.279514
# ..      ...      ...  ...   ...       ...     ...        ...        ...
# 386  160821       KO  Fem  Tx05     Basal  DG_mol   0.285884   0.491404
# 388  160821       KO  Fem  Tx05     Basal   CA3_p   1.000000   0.000000
# 390  160821       KO  Fem  Tx05     Basal   CA3_r   0.653106  -0.032558
# 392  160821       KO  Fem  Tx05     Basal   CA1_p   0.222745  -0.700255
# 394  160821       KO  Fem  Tx05     Basal   CA1_r   0.710817   0.087581
#
#         Pinch      Diff   Group
# 0    0.312855  0.061648   WTTx1
# 2    0.393122  0.093529   WTTx1
# ...

# %%
sns.boxplot(data = coh_bs[coh_bs['Genotype']=='WT'], x = 'Site', y = 'Diff', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False)

# %% [markdown]
# ## Between genotypes

# %%
basal = melt_abs[(melt_abs['Tx'] != 'Tx1') &(melt_abs['Condition']=='Basal')].copy()
pinch = melt_abs[(melt_abs['Tx'] != 'Tx1') &(melt_abs['Condition']=='Pinch')].copy()

# %%
basal['Group'] = basal['Genotype'] + basal['Tx']
pinch['Group'] = pinch['Genotype'] + pinch['Tx']

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.subplot(321)
sns.boxplot(data = basal[basal['Site']== 'DG'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax1)
plt.yscale('log')
ax1.set_title('DG')
ax2 = plt.subplot(322)
sns.boxplot(data = basal[basal['Site']== 'DG_mol'], x = 'band', y = 'power', hue = 'Group',hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax2)
ax2.set_title('DGmol')
plt.yscale('log')

ax3 = plt.subplot(323)
sns.boxplot(data = basal[basal['Site']== 'CA3_p'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax3)
plt.yscale('log')
ax3.set_title('CA3p')
ax4 = plt.subplot(324)
sns.boxplot(data = basal[basal['Site']== 'CA3_r'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax4)
ax4.set_title('CA3r')
plt.yscale('log')

ax5 = plt.subplot(325)
sns.boxplot(data = basal[basal['Site']== 'CA1_p'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax5)
plt.yscale('log')
ax5.set_title('CA1p')
ax6 = plt.subplot(326)
sns.boxplot(data = basal[basal['Site']== 'CA1_r'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax6)
ax6.set_title('CA1r')
plt.yscale('log')

plt.tight_layout()

# %% [markdown]
# ## Basal WT vs KO

# %%
r_basal = melt_rel[(melt_rel['Tx'] != 'Tx1') &(melt_rel['Condition']=='Basal')].copy()
r_pinch = melt_rel[(melt_rel['Tx'] != 'Tx1') &(melt_rel['Condition']=='Pinch')].copy()

# %%
r_basal['Group'] = r_basal['Genotype'] + r_basal['Tx']
r_pinch['Group'] = r_pinch['Genotype'] + r_pinch['Tx']

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.subplot(321)
sns.boxplot(data = r_basal[r_basal['Site']== 'DG'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax1)

ax1.set_title('DG')
ax2 = plt.subplot(322)
sns.boxplot(data = r_basal[r_basal['Site']== 'DG_mol'], x = 'band', y = 'power', hue = 'Group',hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax2)
ax2.set_title('DGmol')

ax3 = plt.subplot(323)
sns.boxplot(data = r_basal[r_basal['Site']== 'CA3_p'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax3)

ax3.set_title('CA3p')
ax4 = plt.subplot(324)
sns.boxplot(data = r_basal[r_basal['Site']== 'CA3_r'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax4)
ax4.set_title('CA3r')


ax5 = plt.subplot(325)
sns.boxplot(data = r_basal[r_basal['Site']== 'CA1_p'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax5)

ax5.set_title('CA1p')
ax6 = plt.subplot(326)
sns.boxplot(data = r_basal[r_basal['Site']== 'CA1_r'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax6)
ax6.set_title('CA1r')


plt.tight_layout()

# %% [markdown]
# ## Relative basal

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.subplot(321)
sns.boxplot(data = pinch[pinch['Site']== 'DG'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax1)
plt.yscale('log')
ax1.set_title('DG')
ax2 = plt.subplot(322)
sns.boxplot(data = pinch[pinch['Site']== 'DG_mol'], x = 'band', y = 'power', hue = 'Group',hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax2)
ax2.set_title('DGmol')
plt.yscale('log')

ax3 = plt.subplot(323)
sns.boxplot(data = pinch[pinch['Site']== 'CA3_p'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax3)
plt.yscale('log')
ax3.set_title('CA3p')
ax4 = plt.subplot(324)
sns.boxplot(data = pinch[pinch['Site']== 'CA3_r'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax4)
ax4.set_title('CA3r')
plt.yscale('log')

ax5 = plt.subplot(325)
sns.boxplot(data = pinch[pinch['Site']== 'CA1_p'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax5)
plt.yscale('log')
ax5.set_title('CA1p')
ax6 = plt.subplot(326)
sns.boxplot(data = pinch[pinch['Site']== 'CA1_r'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax6)
ax6.set_title('CA1r')
plt.yscale('log')

plt.tight_layout()

# %% [markdown]
# ## Pinch absolute

# %%
plt.figure(figsize=(12, 12))
ax1 = plt.subplot(321)
sns.boxplot(data = r_pinch[r_pinch['Site']== 'DG'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax1)

ax1.set_title('DG')
ax2 = plt.subplot(322)
sns.boxplot(data = r_pinch[r_pinch['Site']== 'DG_mol'], x = 'band', y = 'power', hue = 'Group',hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax2)
ax2.set_title('DGmol')

ax3 = plt.subplot(323)
sns.boxplot(data = r_pinch[r_pinch['Site']== 'CA3_p'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax3)

ax3.set_title('CA3p')
ax4 = plt.subplot(324)
sns.boxplot(data = r_pinch[r_pinch['Site']== 'CA3_r'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax4)
ax4.set_title('CA3r')


ax5 = plt.subplot(325)
sns.boxplot(data = r_pinch[r_pinch['Site']== 'CA1_p'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax5)

ax5.set_title('CA1p')
ax6 = plt.subplot(326)
sns.boxplot(data = r_pinch[r_pinch['Site']== 'CA1_r'], x = 'band', y = 'power', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax6)
ax6.set_title('CA1r')


plt.tight_layout()

# %% [markdown]
# ## Relative pinch

# %%
coh_pool['Group'] = coh_pool['Genotype']+coh_pool['Tx']

# %%
plt.figure(figsize=(16, 6))
ax1 = plt.subplot(121)
sns.boxplot(data = coh_pool[(coh_pool['Group']!='WTTx1') & (coh_pool['Condition']== 'Basal')], x = 'Site', y = 'theta_coh', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax1)
ax2 = plt.subplot(122)
sns.boxplot(data = coh_pool[(coh_pool['Group']!='WTTx1') & (coh_pool['Condition']== 'Basal')], x = 'Site', y = 'phase_lag', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax2)

# %%
plt.figure(figsize=(16, 6))
ax1 = plt.subplot(121)
sns.boxplot(data = coh_pool[(coh_pool['Group']!='WTTx1') & (coh_pool['Condition']== 'Pinch')], x = 'Site', y = 'theta_coh', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax1)
ax2 = plt.subplot(122)
sns.boxplot(data = coh_pool[(coh_pool['Group']!='WTTx1') & (coh_pool['Condition']== 'Pinch')], x = 'Site', y = 'phase_lag', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True, ax = ax2)

# %%
coh_bs['Group'] = coh_bs['Genotype']+coh_bs['Tx']
# Out:
# <ipython-input-240-a12b896e34d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coh_bs['Group'] = coh_bs['Genotype']+coh_bs['Tx']

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data = coh_bs[coh_bs['Group']!='WTTx1'], x = 'Site', y = 'Diff', hue = 'Group', hue_order = ['WTPl', 'WTTx05', 'KOPl', 'KOTx05'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.4, palette=['royalblue', 'steelblue', 'forestgreen', 'darkseagreen'], showfliers = False, dodge = True)

# %%
coh_bs
# Out:
#        Date Genotype  Sex    Tx Condition    Site  theta_coh  phase_lag  \
# 0    271021       WT  Fem   Tx1     Basal      DG   0.251207   1.961989
# 2    271021       WT  Fem   Tx1     Basal  DG_mol   0.299593   0.646919
# 4    271021       WT  Fem   Tx1     Basal   CA3_p   1.000000   0.000000
# 6    271021       WT  Fem   Tx1     Basal   CA3_r   0.888157   0.110572
# 8    271021       WT  Fem   Tx1     Basal   CA1_p   0.220640  -1.279514
# ..      ...      ...  ...   ...       ...     ...        ...        ...
# 386  160821       KO  Fem  Tx05     Basal  DG_mol   0.285884   0.491404
# 388  160821       KO  Fem  Tx05     Basal   CA3_p   1.000000   0.000000
# 390  160821       KO  Fem  Tx05     Basal   CA3_r   0.653106  -0.032558
# 392  160821       KO  Fem  Tx05     Basal   CA1_p   0.222745  -0.700255
# 394  160821       KO  Fem  Tx05     Basal   CA1_r   0.710817   0.087581
#
#         Pinch      Diff   Group
# 0    0.312855  0.061648   WTTx1
# 2    0.393122  0.093529   WTTx1
# ...

# %% [markdown]
# ## Focus on CA1

# %%
wt_ca1 = melt_abs[(melt_abs['Genotype'] == 'WT') &(melt_abs['Site'].isin(['CA1_p', 'CA1_r']))].copy()

# %%
wt_ca1rel = melt_rel[(melt_rel['Genotype'] == 'WT') &(melt_rel['Site'].isin(['CA1_p', 'CA1_r']))].copy()

# %%
ca1_basal = plt.figure(figsize=(12, 4))
ax1 = plt.subplot(121)
sns.boxplot(data = wt_ca1[(wt_ca1['Site']== 'CA1_p') & (wt_ca1['Condition'] == 'Basal')], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)
plt.yscale('log')
ax1.set_title('CA1_p')
ax2 = plt.subplot(122)
sns.boxplot(data = wt_ca1[(wt_ca1['Site']== 'CA1_r') & (wt_ca1['Condition'] == 'Basal')], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)
ax2.set_title('CA1_r')
plt.yscale('log')

ca1_basal.suptitle('Basal Absolute Power Distribution')

plt.tight_layout()

# %%
ca1_rel = plt.figure(figsize=(12, 8))
ax3 = plt.subplot(221)
sns.boxplot(data = wt_ca1rel[(wt_ca1rel['Site']== 'CA1_p') & (wt_ca1rel['Condition'] == 'Basal') & (wt_ca1rel['band'].isin(['delta_rel', 'theta_rel']))], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax3)
ax3.set_title('CA1p')

ax4 = plt.subplot(222)
sns.boxplot(data = wt_ca1rel[(wt_ca1rel['Site']== 'CA1_r') & (wt_ca1rel['Condition'] == 'Basal') & (wt_ca1rel['band'].isin(['delta_rel', 'theta_rel']))], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax4)
ax4.set_title('CA1r')

ax5 = plt.subplot(223)
sns.boxplot(data = wt_ca1rel[(wt_ca1rel['Site']== 'CA1_p') & (wt_ca1rel['Condition'] == 'Basal') & (wt_ca1rel['band'].isin(['gamma_slow_rel', 'gamma_fast_rel']))], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax5)
ax5.set_title('CA1p')

ax6 = plt.subplot(224)
sns.boxplot(data = wt_ca1rel[(wt_ca1rel['Site']== 'CA1_r') & (wt_ca1rel['Condition'] == 'Basal') & (wt_ca1rel['band'].isin(['gamma_slow_rel', 'gamma_fast_rel']))], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax6)
ax6.set_title('CA1r')

ca1_rel.suptitle('Basal Relative Power Distribution')

plt.tight_layout()

# %% [markdown]
# ## Basal WT

# %%
ca1_pinch = plt.figure(figsize=(12, 4))
ax1 = plt.subplot(121)
sns.boxplot(data = wt_ca1[(wt_ca1['Site']== 'CA1_p') & (wt_ca1['Condition'] == 'Pinch')], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)
plt.yscale('log')
ax1.set_title('CA1_p')
ax2 = plt.subplot(122)
sns.boxplot(data = wt_ca1[(wt_ca1['Site']== 'CA1_r') & (wt_ca1['Condition'] == 'Pinch')], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)
ax2.set_title('CA1_r')
plt.yscale('log')

ca1_pinch.suptitle('Pinch Asbolute POwer Distribution')

plt.tight_layout()

# %%
ca1_pinch_rel = plt.figure(figsize=(12, 8))
ax3 = plt.subplot(221)
sns.boxplot(data = wt_ca1rel[(wt_ca1rel['Site']== 'CA1_p') & (wt_ca1rel['Condition'] == 'Pinch') & (wt_ca1rel['band'].isin(['delta_rel', 'theta_rel']))], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax3)
ax3.set_title('CA1p')

ax4 = plt.subplot(222)
sns.boxplot(data = wt_ca1rel[(wt_ca1rel['Site']== 'CA1_r') & (wt_ca1rel['Condition'] == 'Pinch') & (wt_ca1rel['band'].isin(['delta_rel', 'theta_rel']))], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax4)
ax4.set_title('CA1r')

ax5 = plt.subplot(223)
sns.boxplot(data = wt_ca1rel[(wt_ca1rel['Site']== 'CA1_p') & (wt_ca1rel['Condition'] == 'Pinch') & (wt_ca1rel['band'].isin(['gamma_slow_rel', 'gamma_fast_rel']))], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax5)
ax5.set_title('CA1p')

ax6 = plt.subplot(224)
sns.boxplot(data = wt_ca1rel[(wt_ca1rel['Site']== 'CA1_r') & (wt_ca1rel['Condition'] == 'Pinch') & (wt_ca1rel['band'].isin(['gamma_slow_rel', 'gamma_fast_rel']))], x = 'band', y = 'power', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax6)
ax6.set_title('CA1r')

ca1_pinch_rel.suptitle('Pinch Relative Power Distribution')

plt.tight_layout()

# %% [markdown]
# ## Pinch Bands

# %%
ca1_coh = plt.figure(figsize=(10, 8))
ax1 = plt.subplot(221)
sns.boxplot(data = coh_pool[(coh_pool['Genotype']=='WT') & (coh_pool['Condition']== 'Basal') & (coh_pool['Site'].isin(['CA1_p', 'CA1_r']))], x = 'Site', y = 'theta_coh', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax1)
ax1.set_title('Basal')
ax2 = plt.subplot(222)
sns.boxplot(data = coh_pool[(coh_pool['Genotype']=='WT') & (coh_pool['Condition']== 'Basal') & (coh_pool['Site'].isin(['CA1_p', 'CA1_r']))], x = 'Site', y = 'phase_lag', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax2)
ax3 = plt.subplot(223)
sns.boxplot(data = coh_pool[(coh_pool['Genotype']=='WT') & (coh_pool['Condition']== 'Pinch') & (coh_pool['Site'].isin(['CA1_p', 'CA1_r']))], x = 'Site', y = 'theta_coh', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax3)
ax3.set_title('Pinch')
ax4 = plt.subplot(224)
sns.boxplot(data = coh_pool[(coh_pool['Genotype']=='WT') & (coh_pool['Condition']== 'Pinch') & (coh_pool['Site'].isin(['CA1_p', 'CA1_r']))], x = 'Site', y = 'phase_lag', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False, ax = ax4)

ca1_coh.suptitle('CA1 theta band coherence')
plt.tight_layout()

# %%
sns.boxplot(data = coh_bs[(coh_bs['Genotype']=='WT') & (coh_bs['Site'].isin(['CA1_p', 'CA1_r']))], x = 'Site', y = 'Diff', hue = 'Tx', hue_order = ['Tx1', 'Tx05', 'Pl'], showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['cornflowerblue', 'royalblue', 'steelblue'], showfliers = False)

# %%
r_basal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1b6bd9fd92d3> in <module>
# ----> 1 r_basal
#
# NameError: name 'r_basal' is not defined
