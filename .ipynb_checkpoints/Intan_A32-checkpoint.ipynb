# %%
from matplotlib import pyplot as plt
from neo.rawio import IntanRawIO as intanIO
from scipy import signal
import pandas as pd
import numpy as np
from scipy.integrate import simps
import os

# %%
int_dir = '/Volumes/Seagate Expansion Drive/Intan_Exp/090821_KO_54_6_Fem_Pl/KO_Fem_Pl_Gating__210809_195208'

# %%
gating_files = os.listdir(int_dir)[27:127]
shank_one = [6, 3, 14, 4, 10, 12, 11, 5]

# %%
sweep = int_dir + '/'+ gating_files[0]
reader = intanIO(filename = sweep)

# %%
reader.parse_header()

# %%
sampling_rate = reader.get_signal_sampling_rate(channel_indexes= [3])
t_start = reader.get_signal_t_start(block_index=0, seg_index=0, channel_indexes= [3])
units =reader.header['signal_channels'][3]['units']

shank_sweep = np.zeros((8, 55168))

for chnl_id, channel in enumerate(reversed(shank_one)):
    
    raw_sigs = reader.get_analogsignal_chunk(block_index=0, seg_index=0,channel_indexes=[channel], i_start = 0, i_stop = 55168)
    scaled_sigs = reader.rescale_signal_raw_to_float(raw_sigs, dtype='float64', channel_indexes= [channel])
    shank_sweep[chnl_id, :] = scaled_sigs.flatten()

# %%
mean_seep = np.mean(shank_sweep, 0)

# %%
time = np.arange(t_start , 55168/25000, 1/25000)

# %% [markdown]
# ### Shank 1
#
# #### En orden descendente

# %%
fig, axs = plt.subplots(nrows = 8, ncols = 1, sharex = True, figsize = (15, 10))
for ax_id, ax in enumerate(axs):
    ax.plot(time, shank_sweep[ax_id, :], linewidth = 1)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# %% [markdown]
# #### La longitud del shank permite la cobertura de CA1-CA3

# %% [markdown]
# ### Estimulación auditiva
#
# #### Cambio de dosis de anestesia: máxima dosis 1.5 g/kg

# %%
new_dir = '/Volumes/Seagate Expansion Drive/Intan_Exp/170821_KO_55_2_Fem_Tx05/KO_Fem_Tx05_Gating_210817_174617/'

# %%
new_files = os.listdir(new_dir)[1:150]

# %%
sweep = new_dir + new_files[0]
reader = intanIO(filename = sweep)

# %%
reader.parse_header()

# %% [markdown]
# ### Verifying recording properties

# %%
reader.header
# Out:
# {'nb_block': 1,
#  'nb_segment': [1],
#  'signal_channels': array([('A-000',  0, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-001',  1, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-002',  2, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-003',  3, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-004',  4, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-005',  5, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-006',  6, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-007',  7, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-008',  8, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-009',  9, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-010', 10, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-011', 11, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-012', 12, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-013', 13, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-014', 14, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-015', 15, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-016', 16, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-017', 17, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-018', 18, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-019', 19, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-020', 20, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-021', 21, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-022', 22, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-023', 23, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-024', 24, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-025', 25, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-026', 26, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-027', 27, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-028', 28, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-029', 29, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-030', 30, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-031', 31, 25000., 'uint16', 'uV', 1.9500e-01, -6389.76, 0),
#         ('A-AUX1', 32,  6250., 'uint16', 'V', 3.7400e-05,     0.  , 1),
#         ('A-AUX2', 33,  6250., 'uint16', 'V', 3.7400e-05,     0.  , 1),
#         ('A-AUX3', 34,  6250., 'uint16', 'V', 3.7400e-05,     0.  , 1),
#         ('ANALOG-IN-07', 35, 25000., 'uint16', 'V', 5.0354e-05,     0.  , 3)],
#        dtype=[('name', '<U64'), ('id', '<i8'), ('sampling_rate', '<f8'), ('dtype', '<U16'), ('units', '<U64'), ('gain', '<f8'), ('offset', '<f8'), ('group_id', '<i8')]),
#  'unit_channels': array([],
#        dtype=[('name', '<U64'), ('id', '<U64'), ('wf_units', '<U64'), ('wf_gain', '<f8'), ('wf_offset', '<f8'), ('wf_left_sweep', '<i8'), ('wf_sampling_rate', '<f8')]),
#  'event_channels': array([], dtype=[('name', '<U64'), ('id', '<U64'), ('type', 'S5')])}

# %% [markdown]
# #### All channels with analog singal checked; 32
# #### Accelerometer signals checked; 3
# #### Triger signal checked; 1

# %%
for ii in range(0, 36):
    name = reader.header['signal_channels'][ii][0]
    size = reader.get_signal_size(block_index=0, seg_index=0,channel_indexes = [ii])
    print(f'{name}; size: {size}')
# Out:
# A-000; size: 55040
# A-001; size: 55040
# A-002; size: 55040
# A-003; size: 55040
# A-004; size: 55040
# A-005; size: 55040
# A-006; size: 55040
# A-007; size: 55040
# A-008; size: 55040
# A-009; size: 55040
# A-010; size: 55040
# A-011; size: 55040
# A-012; size: 55040
# A-013; size: 55040
# A-014; size: 55040
# A-015; size: 55040
# A-016; size: 55040
# A-017; size: 55040
# A-018; size: 55040
# A-019; size: 55040
# A-020; size: 55040
# A-021; size: 55040
# A-022; size: 55040
# A-023; size: 55040
# A-024; size: 55040
# A-025; size: 55040
# A-026; size: 55040
# A-027; size: 55040
# A-028; size: 55040
# A-029; size: 55040
# A-030; size: 55040
# A-031; size: 55040
# A-AUX1; size: 13760
# A-AUX2; size: 13760
# A-AUX3; size: 13760
# ANALOG-IN-07; size: 55040

# %% [markdown]
# ### All analog signals are same size, including trigger from Master-8 (ANALOG-IN-07)

# %%
sf = reader.get_signal_sampling_rate(channel_indexes= [0]) # Any signal channel suffices, not AUX channel though
rec_size = reader.get_signal_size(block_index=0, seg_index=0,channel_indexes = [0])

# %%
# Time vector
time = np.arange(-1.0 , (rec_size/sf)-1, 1/sf)

# %% [markdown]
# #### Let's check trigger signal

# %%
analog_1 = reader.get_analogsignal_chunk(block_index=0, seg_index=0,channel_indexes=[35], i_start = 0, i_stop = rec_size)
analog_scaled = reader.rescale_signal_raw_to_float(analog_1, dtype='float64', channel_indexes= [35])

# %%
plt.plot(time, analog_scaled)

# %% [markdown]
# # Sweeps have different sizes!!!

# %%
for file in new_files:
    sweep = new_dir + file
    reader = intanIO(filename = sweep)
    reader.parse_header()
    print(reader.get_signal_size(block_index=0, seg_index=0,channel_indexes = [0]))
# Out:
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040
# 55040
# 55168
# 55040

# %% [markdown]
# ## But are aligned to trigger properly

# %%
plt.figure(figsize = (16, 4))
triggers = []
for file in new_files:
    sweep = new_dir + file
    reader = intanIO(filename = sweep)
    reader.parse_header()
    size = reader.get_signal_size(block_index=0, seg_index=0,channel_indexes = [0])
    analog_1 = reader.get_analogsignal_chunk(block_index=0, seg_index=0,channel_indexes=[35], i_start = 0, i_stop = size)
    analog_scaled = reader.rescale_signal_raw_to_float(analog_1, dtype='float64', channel_indexes= [35])
    trigger_id, _ = signal.find_peaks(analog_scaled.flatten(), height = 1.5)
    triggers.append(trigger_id[0])
    plt.plot(analog_scaled, linewidth = 0.2)

# %%
p, _ = signal.find_peaks(analog_scaled.flatten(), height = 1.5)

# %%
np.nonzero(analog_scaled > 1.5)
# Out:
# (array([25040, 25041, 25042, ..., 27533, 27534, 27535]),
#  array([0, 0, 0, ..., 0, 0, 0]))

# %%
A32_4x8 = {'shank_4' : [5, 11, 12, 10, 4, 14, 3, 6], 'shank_3' : [8, 13, 9, 2, 7, 15, 1, 0],         # Shank numbering is right most to left
           'shank_2' : [29, 24, 18, 19, 31, 23, 16, 28], 'shank_1' :[27, 17, 22, 21, 20, 26, 25, 30]} # That is from medial to lateral

# %%
shank_array = np.zeros((8, 27500))
channel_0 = np.zeros((150, 27500)) # allocate for working channels
channel_1 = np.zeros((150, 27500))
channel_2 = np.zeros((150, 27500))
channel_3 = np.zeros((150, 27500))
channel_4 = np.zeros((150, 27500))
channel_5 = np.zeros((150, 27500))
channel_6 = np.zeros((150, 27500))
channel_7 = np.zeros((150, 27500))

# %%
channels_ = [channel_0, channel_1, channel_2, channel_3, channel_4, channel_5, channel_6, channel_7]

# %%
fNQ = 25000 / 2               # Determine the Nyquist frequency.
n = 10                     # Define the filter order
Wn = 350 / fNQ                  # ... and specify the cutoff frequency,
b = signal.butter(n, Wn, 'low')              # ... build lowpass filter.

# %%
for file_idx, file in enumerate(new_files):
    #print(f'File: {file_idx}')
    sweep = new_dir + file
    reader = intanIO(filename = sweep)
    reader.parse_header()
    size = reader.get_signal_size(block_index=0, seg_index=0,channel_indexes = [0]) # get the size of recording
    analog_1 = reader.get_analogsignal_chunk(block_index=0, seg_index=0,channel_indexes=[35], i_start = 0, i_stop = size) # read analog_in
    analog_scaled = reader.rescale_signal_raw_to_float(analog_1, dtype='float64', channel_indexes= [35])
    trigger_id, _ = signal.find_peaks(analog_scaled.flatten(), height = 1.5) # find trigger signal
    roi = (trigger_id[0]-2500, trigger_id[0]+25000) # region of interest within recording (100 ms before trigger to 1 sec after)

    for ch_idx, channel in enumerate(A32_4x8['shank_4']):
        raw_sig = reader.get_analogsignal_chunk(block_index=0, seg_index=0,channel_indexes=[channel], i_start = roi[0], i_stop = roi[1]) # read analog_in
        sig_scaled = reader.rescale_signal_raw_to_float(raw_sig, dtype='float64', channel_indexes= [channel])
        lfp = signal.filtfilt(b[0], b[1], sig_scaled, axis = 0) # Zero-phase filter each trial
        
        channels_[ch_idx][file_idx, :] = lfp.flatten()

# %%
for ii in range(8):
    channel_mean = channels_[ii].mean(0)
    shank_array[ii, :] = channel_mean

# %%
time_roi = np.arange(-0.1, (27500/25000)-0.1, 1/25000)

# %%
fig, axs = plt.subplots(nrows = 8, ncols = 1, sharex = True, figsize = (15, 10))
for ax_id, ax in enumerate(axs):
    ax.plot(time_roi, shank_array[ax_id, :], linewidth = 1)
    ax.vlines(x = 0.0, ymin = -25, ymax = 25, colors='r', linestyles='dotted')
    ax.vlines(x = 0.5, ymin = -25, ymax = 25, colors='r', linestyles='dotted')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

# %%
pep_mat = np.zeros((4, 8, 150, 5000))

# %%
for file_idx, file in enumerate(new_files):
    #print(f'File: {file_idx}')
    sweep = new_dir + file
    reader = intanIO(filename = sweep)
    reader.parse_header()
    size = reader.get_signal_size(block_index=0, seg_index=0,channel_indexes = [0]) # get the size of recording
    analog_1 = reader.get_analogsignal_chunk(block_index=0, seg_index=0,channel_indexes=[35], i_start = 0, i_stop = size) # read analog_in
    analog_scaled = reader.rescale_signal_raw_to_float(analog_1, dtype='float64', channel_indexes= [35])
    trigger_id, _ = signal.find_peaks(analog_scaled.flatten(), height = 1.5) # find trigger signal
    roi = (trigger_id[0], trigger_id[0]+5000) # region of interest within recording (100 ms before trigger to 1 sec after)

    for shank in A32_4x8:
        sh_idx = int(shank[-1])-1
        for ch_idx, channel in enumerate(A32_4x8[shank]):
            raw_sig = reader.get_analogsignal_chunk(block_index=0, seg_index=0,channel_indexes=[channel], i_start = roi[0], i_stop = roi[1]) # read analog_in
            sig_scaled = reader.rescale_signal_raw_to_float(raw_sig, dtype='float64', channel_indexes= [channel])
            lfp = signal.filtfilt(b[0], b[1], sig_scaled, axis = 0) # Zero-phase filter each trial

            pep_mat[sh_idx, ch_idx, file_idx, :] = lfp.flatten()

# %%
pep_mean = pep_mat.mean(2)

# %%
pep_mean.shape
# Out:
# (4, 8, 5000)

# %%
pep_32, axs = plt.subplots(nrows = 8, ncols = 4, figsize = (8, 5))
for column in range(4):
    for row in range(8):
        axs[row, column].plot(pep_mean[column, row])
        axs[row, column].set_axis_off()
plt.annotate('CA1', (0.92,0.87), xycoords = 'figure fraction', fontsize = 12)
plt.annotate('CA3', (0.92,0.23), xycoords = 'figure fraction', fontsize = 12)
plt.annotate('Medial', (0.79,0.05), xycoords = 'figure fraction', fontsize = 12)
plt.annotate('Lateral', (0.1,0.05), xycoords = 'figure fraction', fontsize = 12)
# Out:
# Text(0.1, 0.05, 'Lateral')

# %%
pep_32.savefig('/Users/labc02/Desktop/PEP_map32.svg')
