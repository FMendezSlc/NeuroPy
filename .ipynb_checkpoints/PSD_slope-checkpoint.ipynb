# %% [markdown]
# ### Testing PSD slope for E:I balance

# %%
import os as os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
def PSD_slope(psd, frqs, band = (band), min_samples = min_samples):
    '''Function to fit a linear regression over the region of the PSD specified by band.\n
    Two models are fitted: simple linear regression and RANSAC (robust) regression.\n
    Residuals of both models are compared with R squared and the best fit is kept.\n
    psd (pandas.Series) Relative power for each frecuency\n
    frqs (pandas.Series) Frecuency in Hz for each power datum.\n
    band (tupple) Limits for the band of interest.\n
    min_samples (int) Minimal number of samples to keep in the robust regression.
    '''
    
    mask = np.logical_and(frqs>= band[0], frqs<= band[1])
    X_fit = np.reshape(np.log10(frqs[mask].values), (-1,1))
    Y_fit = np.reshape(np.log10(psd[mask].values), (-1,1))
    
    # Fit ordinary linear regression
    lr = linear_model.LinearRegression()
    lr.fit(X_fit, Y_fit)
    
    lr_p = lr.predict(X_fit)
    # R^2 Score
    lr_score = r2_score(Y_fit, lr_p)
    
    # Fit RANSAC
    rm = linear_model.RANSACRegressor(min_samples = min_samples, max_trials = 500)
    rm.fit(X_fit, Y_fit)
    
    rm_p =rm.predict(X_fit)
    rm_score = r2_score(Y_fit[rm.inlier_mask_], rm_p[rm.inlier_mask_])
    
    if lr_score > rm_score:
        print('Best fit: Ordinary Linear Regression')
        print(f'intercept: {lr.intercept_} \nslope {lr.coef_}')
        best_fit = lr_p
        slope = lr.coef_
        intercept = lr.intercept_
        r_sq = lr_score
        print(f'R^2= {r_sq}\nVS\n{rm_score}')
    else:
        print('Best fit: RANSAC Regression')
        print(f'intercept: {rm.estimator_.intercept_} \nslope {rm.estimator_.coef_}')
        best_fit = rm_p
        slope = rm.estimator_.coef_
        intercept = rm.estimator_.intercept_
        r_sq = rm_score
        print(f'R^2= {r_sq}\nVS\n{lr_score}')
        
    fig = plt.figure(figsize=(8, 4))
    plt.subplot(121)
    plt.plot(np.log10(frqs), np.log10(psd), linewidth = 0.5)
    plt.plot(np.log10(frqs[mask]), np.log10(psd[mask]), 'r--', linewidth = 0.7)
    plt.ylabel('Rel. Power (dB)')
    plt.xlabel('Fq. log(Hz)')
    plt.subplot(122)
    plt.plot(np.log10(frqs[mask]), np.log10(psd[mask]), linewidth = 0.5)
    plt.plot(np.log10(fqs[mask]), best_fit, 'r--')
    plt.ylabel('Rel. Power (dB)')
    plt.xlabel('Fq. log(Hz)')
    
    return (slope, intercept, r_sq), fig

# %%
def meta(file_name):
     '''Get the meta data for each file: ID, Genotype, Sex, Tx'''
     meta_bits = file.split('_')
     ID = meta_bits[0]
     gen = meta_bits[1]
     tx = meta_bits[2]
     
     meta_tp = (ID, gen, tx)
     return meta_tp

# %%
def preprocess(file_name):
     '''Get the psd and frequency data'''
     
     file_df = pd.read_csv(psd_dir+'/'+file_name)
     fqrs = file_df['Frqs (Hz)'].copy()
     ca1_psd = file_df['CA1_psd'].copy()
     ca3_psd = file_df['CA3_psd'].copy()
     dg_psd = file_df['DG'].copy()
     
     psd_data = (fqrs, ca1_psd, ca3_psd, dg_psd)
     return psd_data

# %%
def process_file(file_name, band = (1, 50), min_samples = 80):
     '''Run the complete process of a file.'''
     
     slope_dic = {'ID':[], 'Genotype':[], 'Tx':[], 'Site':[], 'Model':[], 'Slope':[], 'Intercept':[], 'R^2':[]}
     
     meta_data = meta(file_name) # get the meta data: gen, tx, sex
     psd_data = preprocess(file_name) # get the numeric data

# %%
psd_dir = '/Users/labc02/Documents/PDCB_data/MK-project/LFP_data/Spectral_Long'

# %%
psd_files = [file for file in os.listdir(psd_dir) if 'psd.csv' in file]

# %%
psd_files
# Out:
# ['051021_WT_Tx1_psd.csv',
#  '060921_WT_Pl_psd.csv',
#  '090821_KO_Pl_psd.csv',
#  '100921_WT_Tx1_psd.csv',
#  '10921_WT_Tx1_psd.csv',
#  '110821_KO_Tx05_psd.csv',
#  '120821_KO_Tx05_psd.csv',
#  '121021_WT_Tx05_psd.csv',
#  '131021_WT_Tx05_psd.csv',
#  '140921_WT_Pl_psd.csv',
#  '150921_WT_Tx1_psd.csv',
#  '160821_KO_Tx05_psd.csv',
#  '160921_WT_Pl_psd.csv',
#  '170821_KO_Tx05_psd.csv',
#  '170921_WT_Pl_psd.csv',
#  '180821_KO_Tx05_psd.csv',
#  '190821_KO_Pl_psd.csv',
#  '200921_WT_Tx05_psd.csv',
#  '20921_WT_Tx1_psd.csv',
#  '210921_WT_Tx05_psd.csv',
#  '220921_WT_Tx05_psd.csv',
#  '230821_KO_Pl_psd.csv',
#  '230921_WT_Tx05_psd.csv',
#  '240821_KO_Pl_psd.csv',
#  '250821_KO_Pl_psd.csv',
#  '260821_KO_Tx05_psd.csv',
#  '261021_KO_Tx05_psd.csv',
#  '270921_WT_Tx05_psd.csv',
#  '271021_WT_Tx1_psd.csv',
#  '280921_WT_Pl_psd.csv',
#  '300821_KO_Tx05_psd.csv',
#  '30921_WT_Tx1_psd.csv',
#  '310821_WT_Pl_psd.csv',
#  '41021_WT_Pl_psd.csv',
#  '80921_KO_Pl_psd.csv',
#  '90921_KO_Pl_psd.csv']

# %%
slope_dic = {'ID':[], 'Genotype':[], 'Tx':[], 'Site':[], 'Model':[], 'Slope':[], 'Intercept':[], 'R^2':[]}

# %%
file = '310821_WT_Pl_psd.csv'

# %%
meta = file.split('_')

# %%
meta
# Out:
# ['310821', 'WT', 'Pl', 'psd.csv']

# %%
psd_df = pd.read_csv(f'/Users/labc02/Documents/PDCB_data/MK-project/LFP_data/Spectral_Long/{file}')

# %%
psd_df.columns
# Out:
# Index(['Unnamed: 0', 'Frqs (Hz)', 'DG_psd', 'DG_dB', 'CA3_psd', 'CA3_dB',
#        'CA1_psd', 'CA1_dB'],
#       dtype='object')

# %%
fqs = psd_df['Frqs (Hz)']

# %%
psd = psd_df['CA1_psd']

# %%
params, fig = PSD_slope(psd, fqs, band=(20, 50))
# Out:
# Best fit: RANSAC Regression
# intercept: [2.86032375]
# slope [[-1.4417705]]
# R^2= 0.8375581418701519
# VS
# 0.8183294378065045

# %%
site = 'CA1'
model = 'RANSAC'
slope = params[0].item()
intercept = params[1].item()
r = params[2].item()

# %%
slope_dic['ID'].append(meta[0])
slope_dic['Genotype'].append(meta[1])
slope_dic['Tx'].append(meta[2])
slope_dic['Site'].append(site)
slope_dic['Model'].append(model)
slope_dic['Slope'].append(slope)
slope_dic['Intercept'].append(intercept)
slope_dic['R^2'].append(r)

# %%
slope_dic
# Out:
# {'ID': ['41021',
#   '41021',
#   '41021',
#   '10921',
#   '10921',
#   '10921',
#   '20921',
#   '20921',
#   '20921',
#   '30921',
#   '30921',
#   '30921',
#   '051021',
#   '051021',
#   '051021',
#   '060921',
#   '060921',
#   '060921',
#   '80921',
#   '80921',
#   '80921',
#   '090821',
#   '090821',
#   '090821',
#   '100921',
#   '100921',
#   '100921',
#   '110821',
#   '110821',
#   '110821',
#   '120821',
#   '120821',
#   '120821',
#   '121021',
#   '121021',
#   '121021',
#   '131021',
#   '131021',
#   '131021',
#   '140921',
#   '140921',
#   '140921',
#   '150921',
#   '150921',
#   '150921',
#   '160821',
#   '160821',
#   '160821',
#   '160921',
#   '160921',
#   '160921',
#   '170821',
#   '170821',
#   '170821',
#   '170921',
#   '170921',
#   '170921',
#   '180821',
#   '180821',
#   '180821',
#   '190821',
#   '190821',
#   '190821',
#   '200921',
#   '200921',
#   '200921',
#   '210921',
#   '210921',
#   '210921',
#   '220921',
#   '220921',
#   '220921',
#   '230821',
#   '230821',
#   '230821',
#   '230921',
#   '230921',
#   '230921',
#   '240821',
#   '240821',
#   '240821',
#   '250821',
#   '250821',
#   '250821',
#   '260821',
#   '260821',
#   '260821',
#   '261021'],
#  'Genotype': ['WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'WT',
#   'WT',
#   'WT',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'KO',
#   'KO',
#   'KO',
#   'WT',
#   'WT',
#   'WT',
#   'KO',
#   'KO',
#   'KO',
#   'WT',
#   'WT',
#   'WT',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'WT',
#   'KO',
#   'KO',
#   'KO',
#   'WT',
#   'WT',
#   'WT',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO',
#   'KO'],
#  'Tx': ['Pl',
#   'Pl',
#   'Pl',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Tx1',
#   'Tx1',
#   'Tx1',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Pl',
#   'Tx05',
#   'Tx05',
#   'Tx05',
#   'Tx05'],
#  'Site': ['DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG',
#   'CA3',
#   'CA1',
#   'DG'],
#  'Model': ['RANSAC',
#   'OLR',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC',
#   'RANSAC'],
#  'Slope': [-2.9782105114588004,
#   -2.076092000887916,
#   -4.083222199448954,
#   -2.051701859657137,
#   -2.874245992685179,
#   -2.5904603303978937,
#   0.660765401159771,
#   -1.1193374779362963,
#   -0.8816717654012193,
#   -3.1674801129368135,
#   -3.167710175850151,
#   -1.99036293703493,
#   -0.8575798763172972,
#   -1.6547018886910703,
#   -2.304868349339252,
#   -2.044087224318492,
#   -1.894921180575982,
#   -2.70027673128279,
#   -2.4918487096058195,
#   -1.4402379356914645,
#   -1.422800783915744,
#   -1.4426227887893408,
#   -1.9785981494922662,
#   -1.9191928227494788,
#   -1.4795950310253252,
#   -3.129408443919348,
#   -2.564118544118456,
#   -1.1018291608457393,
#   -0.8007706139059724,
#   -1.294457294727035,
#   -2.484723593203356,
#   -1.5698684865579982,
#   -1.4093272812074187,
#   -1.304341556879186,
#   -1.4225389956164631,
#   -1.195983513878371,
#   -2.059936299722132,
#   -3.0641117366508994,
#   -2.0199768361184423,
#   -1.530122557443386,
#   -1.8539959286461043,
#   -1.8836005741639383,
#   -1.383778280585156,
#   -1.8971804904446825,
#   -1.9598922121943059,
#   -1.03437635414379,
#   -1.5087075608977312,
#   -2.1076838651407415,
#   -3.13084672183321,
#   -2.282624591839247,
#   -4.088729224633824,
#   -1.3746310859746451,
#   -1.0730550639273406,
#   -1.248454168694729,
#   -0.8517403985553211,
#   -0.8958814684142731,
#   -2.1502577712839495,
#   -1.9950964112141394,
#   -1.2475280445112422,
#   -2.5340354642212093,
#   -1.268414433787257,
#   -1.795554855687925,
#   -1.8987372961479292,
#   -2.2022099558201726,
#   -2.5047284119225446,
#   -2.73408011188276,
#   -1.7828651671110736,
#   -1.6417489820404538,
#   -3.536421386081602,
#   -2.2048034167283035,
#   -3.07040177924811,
#   -2.003088073917338,
#   -2.053391703102988,
#   -2.668173686932803,
#   -2.607619351080362,
#   -1.5652019065568794,
#   -1.9904437891977453,
#   -1.7631250108869039,
#   -1.5499245881739596,
#   -0.6149261640444635,
#   -1.5652216376085757,
#   -1.6233513202142036,
#   -1.6057943972561362,
#   -2.601550888718601,
#   -2.3993057071426787,
#   -2.4069934757967104,
#   -0.9557974815720461,
#   -1.6282697301643836],
#  'Intercept': [6.719284230947104,
#   4.507938274396473,
#   7.55470925466666,
#   4.139883128351796,
#   5.957335716102798,
#   4.552326983336251,
#   0.6414007014012968,
#   3.1569425628975574,
#   2.826361716154356,
#   7.420928685537978,
#   6.564557838746721,
#   4.485964720595305,
#   3.2724282368986946,
#   4.1430815483958785,
#   4.367611416317115,
#   5.248105238829885,
#   4.492142311166763,
#   5.7709461457709805,
#   6.027507257139467,
#   3.349928256643043,
#   3.329054671204128,
#   4.289695936658267,
#   4.67805523809729,
#   4.084957364446211,
#   3.9587802782132666,
#   6.28022428035982,
#   4.8586628416040565,
#   3.784073604885188,
#   2.79219893995774,
#   2.8574704565724787,
#   5.347263484479937,
#   3.554663766525425,
#   2.9520741784878344,
#   4.109697837745458,
#   3.7622070974140813,
#   2.8587983759508506,
#   5.17604952549251,
#   6.64320374167321,
#   3.9387683648874967,
#   3.4222902046575054,
#   3.678780279581094,
#   3.553587432200796,
#   4.354376867089638,
#   4.341440078459538,
#   4.090314567652266,
#   3.699898291591161,
#   4.307262413673693,
#   4.476497831817804,
#   6.828234628831403,
#   5.211551916624737,
#   7.520142534822616,
#   4.542797874985606,
#   3.1284894674112427,
#   3.183563982565831,
#   3.351499286818744,
#   2.4496683488576823,
#   4.217252379295683,
#   5.08115106691144,
#   3.584202471188652,
#   5.224201123675554,
#   3.624380681335693,
#   3.822610105994391,
#   3.8409555606120187,
#   5.007222198816616,
#   5.259445561041442,
#   5.222275730054501,
#   5.012672406612346,
#   3.8165366880794176,
#   6.9005476970512545,
#   5.517092439587509,
#   6.146733911552621,
#   4.323272855244964,
#   4.5766603162381,
#   5.306352003391743,
#   5.1598077404627425,
#   4.417928537862965,
#   3.7545670142597847,
#   3.409468449138122,
#   4.228855187997736,
#   2.2737690565413176,
#   3.3151298172964028,
#   4.101408320277996,
#   3.77650226628114,
#   5.053393478178185,
#   5.910702379069598,
#   5.201999850643929,
#   2.810574726452816,
#   4.718269839046029],
#  'R^2': [0.8953125192261318,
#   0.7430697614636819,
#   0.9412791239016207,
#   0.8097340797115904,
#   0.8806883139484156,
#   0.8364328150391126,
#   0.48666854838655227,
#   0.8374885829420593,
#   0.7642961581659208,
#   0.9129196272020685,
#   0.9251462906722224,
#   0.8924815620227906,
#   0.8055083597621556,
#   0.8178394171421892,
#   0.828416919824881,
#   0.851727756027988,
#   0.816035836123534,
#   0.8549423325777639,
#   0.8270279893412807,
#   0.8399753672787276,
#   0.9180380496267768,
#   0.8179728392820695,
#   0.8285871582956531,
#   0.8880137893208496,
#   0.8649466437632233,
#   0.8968063334332398,
#   0.8556735930023582,
#   0.7860988640090456,
#   0.7884479999618235,
#   0.8503078657311793,
#   0.9026458901679352,
#   0.9357686499492855,
#   0.9047478361723279,
#   0.9117051609228288,
#   0.8726240266657044,
#   0.8708416001077791,
#   0.8726741709252733,
#   0.8658506293773842,
#   0.8432110878098839,
#   0.8452585798134576,
#   0.8741398520668939,
#   0.8630066803023397,
#   0.8637380769165609,
#   0.9221826695236824,
#   0.8733447572639984,
#   0.8425185311672985,
#   0.8519692674961152,
#   0.8349866188271383,
#   0.8348068831852299,
#   0.8369280095627052,
#   0.8664934863738089,
#   0.8772910271484914,
#   0.8080101061309186,
#   0.8149642224142606,
#   0.766894067110561,
#   0.8067317928138036,
#   0.8623623676452044,
#   0.8620061585012985,
#   0.8810545303648081,
#   0.8360858608299965,
#   0.8479937777109087,
#   0.8776549867170288,
#   0.8816083414019031,
#   0.8909826120006694,
#   0.8604917033690366,
#   0.8702320546756154,
#   0.8602919337302598,
#   0.8184331882380997,
#   0.9296339522594264,
#   0.8544321646076818,
#   0.8511924441240938,
#   0.8443748828114557,
#   0.8700627341537522,
#   0.9006916790379204,
#   0.8284044961703553,
#   0.8198991505254222,
#   0.8405886716932551,
#   0.8336567560529032,
#   0.8789870489855816,
#   0.6743563051755842,
#   0.8622770250214399,
#   0.9260769672548791,
#   0.8712620488723665,
#   0.9057844613877208,
#   0.8570726258502608,
#   0.8827383398057032,
#   0.7614726605589508,
#   0.8898916154698719]}

# %%
name = file.split('.')[0]
fig.savefig(f'/Users/labc02/Documents/PDCB_data/MK-project/LFP_data/Spectral_Long/{name}_{site}_slope.svg')

# %%
slope_df = pd.DataFrame(slope_dic)

# %%
slope_df.to_csv('/Users/labc02/Documents/PDCB_data/MK-project/LFP_data/Spectral_Long/slope_df.csv')

# %%
import pingouin as pg
# Out:
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.6, the latest is 0.5.0.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.0, the latest is 0.2.1.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
slope_df.columns
# Out:
# Index(['ID', 'Genotype', 'Tx', 'Site', 'Model', 'Slope', 'Intercept', 'R^2'], dtype='object')

# %%
slope_df['Tx'].unique()
# Out:
# array(['Pl', 'Tx1', 'Tx05'], dtype=object)

# %%
sns.boxplot(data = slope_df[slope_df['Genotype']== 'WT'], x = 'Site', y = 'Slope', hue = 'Tx', hue_order = ['Pl', 'Tx05', 'Tx1'])

# %%
plt.subplot(131)
sns.boxplot(data = slope_df[(slope_df['Tx']!= 'Tx1') & (slope_df['Site'] == 'DG')], x = 'Tx', y = 'Slope', hue = 'Genotype', order = ['Pl', 'Tx05'], hue_order = ['WT', 'KO'])
plt.title('DG')
plt.subplot(132)
sns.boxplot(data = slope_df[(slope_df['Tx']!= 'Tx1') & (slope_df['Site'] == 'CA3')], x = 'Tx', y = 'Slope', hue = 'Genotype', order = ['Pl', 'Tx05'], hue_order = ['WT', 'KO'])
plt.title('CA3')
plt.subplot(133)
sns.boxplot(data = slope_df[(slope_df['Tx']!= 'Tx1') & (slope_df['Site'] == 'CA1')], x = 'Tx', y = 'Slope', hue = 'Genotype', order = ['Pl', 'Tx05'], hue_order = ['WT', 'KO'])
plt.title('CA1')
plt.tight_layout()

# %%
pg.anova(data = slope_df[(slope_df['Site']== 'CA3') & (slope_df['Tx']!= 'Tx1')], dv = 'Slope', between = ['Genotype', 'Tx'])
# Out:
#           Source        SS    DF        MS         F     p-unc       np2
# 0       Genotype  1.108029   1.0  1.108029  3.212089  0.085713  0.118039
# 1             Tx  0.291947   1.0  0.291947  0.846330  0.366747  0.034063
# 2  Genotype * Tx  0.712278   1.0  0.712278  2.064839  0.163641  0.079219
# 3       Residual  8.278942  24.0  0.344956       NaN       NaN       NaN

# %%
slope_df['Group'] = slope_df['Genotype'] + '_' + slope_df['Tx']

# %%
pg.pairwise_tukey(data = slope_df[(slope_df['Site']== 'CA3') & (slope_df['Tx']!= 'Tx1')], dv = 'Slope', between = 'Group')
# Out:
#          A        B   mean(A)   mean(B)      diff        se       tail  \
# 0    KO_Pl  KO_Tx05 -1.683881 -1.565201 -0.118680  0.317194  two-sided
# 1    KO_Pl    WT_Pl -1.683881 -1.738976  0.055095  0.326760  two-sided
# 2    KO_Pl  WT_Tx05 -1.683881 -2.261589  0.577708  0.326760  two-sided
# 3  KO_Tx05    WT_Pl -1.565201 -1.738976  0.173775  0.303972  two-sided
# 4  KO_Tx05  WT_Tx05 -1.565201 -2.261589  0.696387  0.303972  two-sided
# 5    WT_Pl  WT_Tx05 -1.738976 -2.261589  0.522613  0.313941  two-sided
#
#           T   p-tukey    hedges
# 0 -0.374155  0.900000 -0.189169
# 1  0.168610  0.900000  0.087261
# 2  1.767988  0.294637  0.914993
# 3  0.571681  0.900000  0.278469
# 4  2.290960  0.108402  1.115938
# 5  1.664685  0.346945  0.833015
