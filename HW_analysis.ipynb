# %% [markdown]
# # Modified Hebb-Williams Maze Task

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pingouin as pg

# %%
hwk_file = pd.read_csv('/Users/labc02/Documents/PDCB_data/Behavior/HWK_complete.csv')

# %%
hwk_test = hwk_file[hwk_file['Task_Phase'].str.contains('Testing')]
# Out:
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.6, the latest is 0.3.10.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
gp_ser = [ii.split('_')[0] for ii in hwk_test['ID']]

# %%
hwk_test['Group'] = gp_ser
# Out:
# <ipython-input-5-31bb6c2e9d67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hwk_test['Group'] = gp_ser

# %%
sns.lineplot(x='Block', y='Error_Count', hue='Gene_type', data=hwk_test, estimator='mean', ci=68, style='Sex', palette=['forestgreen', 'royalblue'], markers=['o', 'v', 'o', 'v'], err_style = 'bars', err_kws={'capsize':2, 'capthick':2})

# %% [markdown]
# Anova de modelo mixto; genotipo como factor entre grupos, bloque como factor repetido

# %% [markdown]
# #### Nos quedamos con solo los 3 dias del protocolo de Kesner

# %%
idx_drop = hwk_test[(hwk_test['Task_Phase']=='Testing_4') | (hwk_test['Task_Phase']=='Testing_5')].index

# %%
hwk_class = hwk_test.drop(idx_drop)

# %%
err_fig.savefig('/Users/labc02/Documents/PDCB_data/Behavior/Figures/error_fig_all_groups.png', dpi=600)

# %%
pg.normality(data=hwk_class, dv='Error_Count', group='Group', method='normaltest')
# Out:
#               W          pval  normal
# KOF  298.810496  1.300545e-65   False
# KOM  420.813529  4.183148e-92   False
# WTF  329.330360  3.067757e-72   False
# WTM  321.408495  1.610765e-70   False

# %%
pg.homoscedasticity(data=hwk_class, dv='Error_Count', group='Group')
# Out:
#                W      pval  equal_var
# levene  6.886568  0.000133      False

# %% [markdown]
# ### No normality, no equal variances, no sphericity

# %%
pg.mixed_anova(data=hwk_class, dv='Error_Count', within='Block', between='Group', subject='ID')
# Out:
#         Source           SS  DF1  DF2          MS          F         p-unc  \
# 0        Group   121.785644    3   42   40.595215   8.203751  2.063985e-04
# 1        Block  1158.004529    5  210  231.600906  85.438940  1.103702e-48
# 2  Interaction   119.372943   15  210    7.958196   2.935826  2.993289e-04
#
#       p-GG-corr       np2       eps sphericity   W-spher       p-spher
# 0           NaN  0.369476       NaN        NaN       NaN           NaN
# 1  1.460330e-22  0.670430  0.458272      False  0.050354  1.399116e-20
# 2           NaN  0.173350       NaN        NaN       NaN           NaN

# %%
pg.pairwise_ttests(data=hwk_class, dv='Error_Count', between='Group', within='Block', subject='ID', padjust='holm')
# Out:
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/pingouin/parametric.py:197: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to "
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/pingouin/effsize.py:689: UserWarning: x and y have unequal sizes. Switching to paired == False.
#   warnings.warn("x and y have unequal sizes. Switching to "
#          Contrast Block     A     B Paired  Parametric          T         dof  \
# 0           Block     -  D1_1  D1_2   True        True   5.536379  229.000000
# 1           Block     -  D1_1  D2_1   True        True   9.005625  229.000000
# 2           Block     -  D1_1  D2_2   True        True  10.046521  229.000000
# 3           Block     -  D1_1  D3_1   True        True  10.137141  229.000000
# 4           Block     -  D1_1  D3_2   True        True  11.314237  241.889277
# 5           Block     -  D1_2  D2_1   True        True   4.315756  229.000000
# 6           Block     -  D1_2  D2_2   True        True   5.334806  229.000000
# 7           Block     -  D1_2  D3_1   True        True   5.623647  229.000000
# 8           Block     -  D1_2  D3_2   True        True   7.248734  256.320921
# 9           Block     -  D2_1  D2_2   True        True   2.844120  229.000000
# 10          Block     -  D2_1  D3_1   True        True   3.194950  229.000000
# 11          Block     -  D2_1  D3_2   True        True   6.791141  384.176155
# 12          Block     -  D2_2  D3_1   True        True   0.977937  229.000000
# 13          Block     -  D2_2  D3_2   True        True   4.306859  409.901850
# 14          Block     -  D3_1  D3_2   True        True   2.509890  352.394740
# 15          Group     -   KOF   KOM  False        True   2.875059   22.000000
# 16          Group     -   KOF   WTF  False        True   4.464321   19.432901
# 17          Group     -   KOF   WTM  False        True   4.520104   22.000000
# 18          Group     -   KOM   WTF  False        True   0.951133   18.616086
# 19          Group     -   KOM   WTM  False        True   0.853502   22.000000
# 20          Group     -   WTF   WTM  False        True  -0.173344   18.978759
# 21  Block * Group  D1_1   KOF   KOM  False        True   2.470325  118.000000
# 22  Block * Group  D1_1   KOF   WTF  False        True   2.906019   98.922723
# 23  Block * Group  D1_1   KOF   WTM  False        True   2.959732  118.000000
# 24  Block * Group  D1_1   KOM   WTF  False        True   0.694234  103.617164
# 25  Block * Group  D1_1   KOM   WTM  False        True   0.601378  118.000000
# 26  Block * Group  D1_1   WTF   WTM  False        True  -0.166070   97.944634
# 27  Block * Group  D1_2   KOF   KOM  False        True   0.684522  118.000000
# 28  Block * Group  D1_2   KOF   WTF  False        True   2.172536   76.825099
# 29  Block * Group  D1_2   KOF   WTM  False        True   1.878545  118.000000
# 30  Block * Group  D1_2   KOM   WTF  False        True   1.072963   72.865150
# 31  Block * Group  D1_2   KOM   WTM  False        True   0.820739  118.000000
# 32  Block * Group  D1_2   WTF   WTM  False        True  -0.513326  107.899867
# 33  Block * Group  D2_1   KOF   KOM  False        True   0.077037  118.000000
# 34  Block * Group  D2_1   KOF   WTF  False        True   1.186630  101.578516
# 35  Block * Group  D2_1   KOF   WTM  False        True   1.440681  118.000000
# 36  Block * Group  D2_1   KOM   WTF  False        True   0.802762  100.300853
# 37  Block * Group  D2_1   KOM   WTM  False        True   0.973766  118.000000
# 38  Block * Group  D2_1   WTF   WTM  False        True   0.199957  105.658396
# 39  Block * Group  D2_2   KOF   KOM  False        True   0.997654  118.000000
# 40  Block * Group  D2_2   KOF   WTF  False        True   2.979742   93.807337
# 41  Block * Group  D2_2   KOF   WTM  False        True   1.396058  118.000000
# 42  Block * Group  D2_2   KOM   WTF  False        True   1.557523   88.493712
# 43  Block * Group  D2_2   KOM   WTM  False        True   0.224741  118.000000
# 44  Block * Group  D2_2   WTF   WTM  False        True  -1.635801  102.860361
# 45  Block * Group  D3_1   KOF   KOM  False        True   2.420567  118.000000
# 46  Block * Group  D3_1   KOF   WTF  False        True   1.158276  103.058949
# 47  Block * Group  D3_1   KOF   WTM  False        True   3.322592  118.000000
# 48  Block * Group  D3_1   KOM   WTF  False        True  -0.797617   70.962216
# 49  Block * Group  D3_1   KOM   WTM  False        True   1.140226  118.000000
# 50  Block * Group  D3_1   WTF   WTM  False        True   1.455712   55.146654
# 51  Block * Group  D3_2   KOF   KOM  False        True   3.962286   65.023287
# 52  Block * Group  D3_2   KOF   WTF  False        True   2.946662   86.848582
# 53  Block * Group  D3_2   KOF   WTM  False        True   2.310651   92.332248
# 54  Block * Group  D3_2   KOM   WTF  False        True  -1.285222   69.925751
# 55  Block * Group  D3_2   KOM   WTM  False        True  -2.283584  118.000000
# 56  Block * Group  D3_2   WTF   WTM  False        True  -0.863304  107.977484
#
#          Tail         p-unc        p-corr p-adjust       BF10    hedges
# 0   two-sided  8.430706e-08  6.744565e-07     holm  1.102e+05  0.487832
# 1   two-sided  8.543467e-17  1.025216e-15     holm  6.066e+13  0.838316
# 2   two-sided  6.547180e-20  8.511334e-19     holm  6.878e+16  0.924677
# 3   two-sided  3.455563e-20  4.837788e-19     holm  1.288e+17  0.941419
# 4   two-sided  4.229028e-24  6.343542e-23     holm  1.195e+23  1.052300
# 5   two-sided  2.367438e-05  1.244760e-04     holm    513.133  0.375319
# 6   two-sided  2.294278e-07  1.605995e-06     holm   4.22e+04  0.494537
# 7   two-sided  5.421168e-08  4.879051e-07     holm  1.684e+05  0.523566
# 8   two-sided  4.952867e-12  5.448154e-11     holm  3.694e+09  0.674267
# 9   two-sided  4.856422e-03  1.456927e-02     holm      3.743  0.230373
# 10  two-sided  1.595408e-03  6.381632e-03     holm      10.24  0.286975
# 11  two-sided  4.242744e-11  4.242744e-10     holm  2.145e+08  0.632320
# 12  two-sided  3.291374e-01  3.291374e-01     holm      0.118  0.088923
# 13  two-sided  2.074601e-05  1.244760e-04     holm    720.135  0.401094
# 14  two-sided  1.252450e-02  2.504900e-02     holm      2.161  0.233639
# 15  two-sided  8.794057e-03  3.517623e-02     holm      5.666  1.133264
# 16  two-sided  2.530717e-04  1.265358e-03     holm     97.068  1.778191
# 17  two-sided  1.693505e-04  1.016103e-03     holm    130.576  1.781693
# 18  two-sided  3.537232e-01  1.000000e+00     holm      0.532  0.375440
# 19  two-sided  4.025786e-01  1.000000e+00     holm      0.486  0.336426
# 20  two-sided  8.642167e-01  1.000000e+00     holm       0.39 -0.071679
# 21  two-sided  1.492844e-02  4.478532e-01     holm      2.942  0.448145
# 22  two-sided  4.517360e-03  1.400382e-01     holm      8.203  0.529340
# 23  two-sided  3.722228e-03  1.248899e-01     holm      9.335  0.536929
# 24  two-sided  4.890892e-01  1.000000e+00     holm      0.252  0.132271
# 25  two-sided  5.487419e-01  1.000000e+00     holm      0.229  0.109097
# 26  two-sided  8.684439e-01  1.000000e+00     holm      0.205 -0.031982
# 27  two-sided  4.949879e-01  1.000000e+00     holm       0.24  0.124180
# 28  two-sided  3.289881e-02  8.553692e-01     holm      1.641  0.385010
# 29  two-sided  6.277431e-02  1.000000e+00     holm      0.946  0.340789
# 30  two-sided  2.868284e-01  1.000000e+00     holm       0.34  0.189280
# 31  two-sided  4.134500e-01  1.000000e+00     holm      0.264  0.148891
# 32  two-sided  6.087728e-01  1.000000e+00     holm      0.228 -0.096256
# 33  two-sided  9.387245e-01  1.000000e+00     holm      0.195  0.013975
# 34  two-sided  2.381416e-01  1.000000e+00     holm      0.381  0.227049
# 35  two-sided  1.523229e-01  1.000000e+00     holm      0.495  0.261356
# 36  two-sided  4.240105e-01  1.000000e+00     holm      0.271  0.146546
# 37  two-sided  3.321649e-01  1.000000e+00     holm      0.298  0.176652
# 38  two-sided  8.418987e-01  1.000000e+00     holm      0.207  0.037899
# 39  two-sided  3.204885e-01  1.000000e+00     holm      0.305  0.180986
# 40  two-sided  3.673233e-03  1.248899e-01     holm      9.871  0.538864
# 41  two-sided  1.653181e-01  1.000000e+00     holm      0.467  0.253261
# 42  two-sided  1.229157e-01  1.000000e+00     holm      0.598  0.279795
# 43  two-sided  8.225695e-01  1.000000e+00     holm      0.199  0.040771
# 44  two-sided  1.049378e-01  1.000000e+00     holm      0.668 -0.299986
# 45  two-sided  1.702064e-02  4.935986e-01     holm      2.644  0.439118
# 46  two-sided  2.494286e-01  1.000000e+00     holm       0.37  0.220956
# 47  two-sided  1.187930e-03  4.157756e-02     holm     24.784  0.602756
# 48  two-sided  4.277536e-01  1.000000e+00     holm       0.27 -0.159798
# 49  two-sided  2.565014e-01  1.000000e+00     holm      0.349  0.206850
# 50  two-sided  1.511419e-01  1.000000e+00     holm      0.522  0.299608
# 51  two-sided  1.870063e-04  6.732228e-03     holm    174.695  0.727230
# 52  two-sided  4.123606e-03  1.319554e-01     holm       9.08  0.534192
# 53  two-sided  2.307903e-02  6.462127e-01     holm      2.109  0.422722
# 54  two-sided  2.029552e-01  1.000000e+00     holm      0.424 -0.257894
# 55  two-sided  2.418501e-02  6.529952e-01     holm      1.993 -0.414268
# 56  two-sided  3.898836e-01  1.000000e+00     holm      0.283 -0.161650

# %%
err_fig = plt.figure()
err_ax =plt.subplot()
sns.lineplot(x='Block', y='Error_Count', hue='Gene_type', data=hwk_class, estimator='mean', ci=68, style='Sex', palette=['forestgreen', 'royalblue'], markers=['o', 'v', 'o', 'v'], err_style = 'bars', err_kws={'capsize':2, 'capthick':2}, ax = err_ax)
err_ax.set_ylabel('Mean Error Count')
err_ax.legend(ncol=2, labels=['KO Fem', 'KO Male', 'WT Fem','WT Male'])
err_ax.set_ylim(0,13)
err_ax.annotate('*', xy=(15, 200), xytext=(15, 200), xycoords='axes points', ha='center',
                va='bottom', arrowprops=dict(arrowstyle='-[, widthB=0.5, lengthB=.1', lw=1, color='k'))
# Out:
# Text(15, 200, '*')

# %% [markdown]
# ### Collapsing Sex, only genotype

# %%
hwk_class['ID'].unique()
# Out:
# array(['KOF_3', 'KOF_0', 'KOF_1', 'KOF_2', 'KOM_0', 'KOM_1', 'KOM_3',
#        'KOM_2', 'WTF_2', 'WTF_1', 'WTF_0', 'WTF_3', 'WTM_0', 'WTM_1',
#        'WTM_2', 'WTM_3', 'KOF_6', 'KOF_5', 'KOF_7', 'KOF_4', 'KOM_5',
#        'KOM_7', 'KOM_6', 'KOM_4', 'WTM_5', 'WTM_7', 'WTM_4', 'WTM_6',
#        'WTF_4', 'WTF_6', 'WTF_5', 'KOF_8', 'KOF_9', 'KOF_10', 'KOF_11',
#        'KOM_8', 'KOM_9', 'KOM_10', 'KOM_11', 'WTF_7', 'WTF_8', 'WTF_9',
#        'WTM_8', 'WTM_9', 'WTM_10', 'WTM_11'], dtype=object)

# %%
err_fig_2.savefig('/Users/labc02/Documents/PDCB_data/Behavior/Figures/error_fig_two_groups.png', dpi=600)

# %%
pg.mixed_anova(data=hwk_class, dv='Error_Count', within='Block', subject='ID', between='Gene_type')
# Out:
#         Source           SS  DF1  DF2          MS          F         p-unc  \
# 0    Gene_type    65.325079    1   44   65.325079  10.875476  1.934352e-03
# 1        Block  1158.004529    5  220  231.600906  80.308232  1.120003e-47
# 2  Interaction    54.165818    5  220   10.833164   3.756428  2.770046e-03
#
#       p-GG-corr       np2       eps sphericity   W-spher       p-spher
# 0           NaN  0.198185       NaN        NaN       NaN           NaN
# 1  1.460330e-22  0.646041  0.458272      False  0.050354  1.399116e-20
# 2           NaN  0.078658       NaN        NaN       NaN           NaN

# %%
pg.pairwise_ttests(data=hwk_class, dv='Error_Count', between='Gene_type', within='Block', subject='ID', padjust='holm')
# Out:
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/pingouin/parametric.py:197: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to "
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/pingouin/effsize.py:689: UserWarning: x and y have unequal sizes. Switching to paired == False.
#   warnings.warn("x and y have unequal sizes. Switching to "
#              Contrast Block     A     B Paired  Parametric          T  \
# 0               Block     -  D1_1  D1_2   True        True   5.536379
# 1               Block     -  D1_1  D2_1   True        True   9.005625
# 2               Block     -  D1_1  D2_2   True        True  10.046521
# 3               Block     -  D1_1  D3_1   True        True  10.137141
# 4               Block     -  D1_1  D3_2   True        True  11.314237
# 5               Block     -  D1_2  D2_1   True        True   4.315756
# 6               Block     -  D1_2  D2_2   True        True   5.334806
# 7               Block     -  D1_2  D3_1   True        True   5.623647
# 8               Block     -  D1_2  D3_2   True        True   7.248734
# 9               Block     -  D2_1  D2_2   True        True   2.844120
# 10              Block     -  D2_1  D3_1   True        True   3.194950
# 11              Block     -  D2_1  D3_2   True        True   6.791141
# 12              Block     -  D2_2  D3_1   True        True   0.977937
# 13              Block     -  D2_2  D3_2   True        True   4.306859
# 14              Block     -  D3_1  D3_2   True        True   2.509890
# 15          Gene_type     -    KO    WT  False        True   3.382902
# 16  Block * Gene_type  D1_1    KO    WT  False        True   2.730752
# 17  Block * Gene_type  D1_2    KO    WT  False        True   2.038820
# 18  Block * Gene_type  D2_1    KO    WT  False        True   1.509687
# 19  Block * Gene_type  D2_2    KO    WT  False        True   1.978832
# 20  Block * Gene_type  D3_1    KO    WT  False        True   1.640730
# 21  Block * Gene_type  D3_2    KO    WT  False        True   1.356307
#
#            dof       Tail         p-unc        p-corr p-adjust       BF10  \
# 0   229.000000  two-sided  8.430706e-08  6.744565e-07     holm  1.102e+05
# 1   229.000000  two-sided  8.543467e-17  1.025216e-15     holm  6.066e+13
# 2   229.000000  two-sided  6.547180e-20  8.511334e-19     holm  6.878e+16
# 3   229.000000  two-sided  3.455563e-20  4.837788e-19     holm  1.288e+17
# 4   241.889277  two-sided  4.229028e-24  6.343542e-23     holm  1.195e+23
# 5   229.000000  two-sided  2.367438e-05  1.244760e-04     holm    513.133
# 6   229.000000  two-sided  2.294278e-07  1.605995e-06     holm   4.22e+04
# 7   229.000000  two-sided  5.421168e-08  4.879051e-07     holm  1.684e+05
# 8   256.320921  two-sided  4.952867e-12  5.448154e-11     holm  3.694e+09
# 9   229.000000  two-sided  4.856422e-03  1.456927e-02     holm      3.743
# 10  229.000000  two-sided  1.595408e-03  6.381632e-03     holm      10.24
# 11  384.176155  two-sided  4.242744e-11  4.242744e-10     holm  2.145e+08
# 12  229.000000  two-sided  3.291374e-01  3.291374e-01     holm      0.118
# 13  409.901850  two-sided  2.074601e-05  1.244760e-04     holm    720.135
# 14  352.394740  two-sided  1.252450e-02  2.504900e-02     holm      2.161
# 15   36.090684  two-sided  1.738770e-03           NaN      NaN     22.121
# 16  208.631018  two-sided  6.859686e-03  4.115811e-02     holm      4.678
# 17  153.344322  two-sided  4.318557e-02  2.159278e-01     holm      1.013
# 18  221.875691  two-sided  1.325461e-01  3.066995e-01     holm      0.421
# 19  209.720238  two-sided  4.914353e-02  2.159278e-01     holm      0.906
# 20  227.851652  two-sided  1.022332e-01  3.066995e-01     holm      0.511
# 21  211.269172  two-sided  1.764492e-01  3.066995e-01     holm      0.343
#
#       hedges
# 0   0.487832
# 1   0.838316
# 2   0.924677
# 3   0.941419
# 4   1.052300
# 5   0.375319
# 6   0.494537
# 7   0.523566
# 8   0.674267
# 9   0.230373
# 10  0.286975
# 11  0.632320
# 12  0.088923
# 13  0.401094
# 14  0.233639
# 15  0.957925
# 16  0.353271
# 17  0.259482
# 18  0.196458
# 19  0.256099
# 20  0.214807
# 21  0.176365

# %%
err_fig_2 = plt.figure()
err_ax2 = plt.subplot()
sns.lineplot(x='Block', y='Error_Count', hue='Gene_type', data=hwk_class, estimator='mean', ci=68, palette=['forestgreen', 'royalblue'], style='Gene_type', dashes=False, markers=['o', 'o'], err_style = 'bars', err_kws={'capsize':2, 'capthick':2}, ax = err_ax2)
err_ax2.set_ylim(0, 10)
err_ax2.annotate('*', xy=(15, 200), xytext=(15, 200), xycoords='axes points', ha='center',
                va='bottom', arrowprops=dict(arrowstyle='-[, widthB=0.5, lengthB=.1', lw=1, color='k'))
err_ax2.legend(ncol=1, labels=['KO', 'WT'])
err_ax2.set_ylabel('Mean Error Count')
# Out:
# Text(0, 0.5, 'Mean Error Count')

# %% [markdown]
# #### Cuantificacion clasica de indices de Kesner

# %%
hw_idx = hwk_class.groupby(['Gene_type', 'Sex', 'ID', 'Block'])['Error_Count'].mean()

# %%
hw_idx = hw_idx.reset_index()

# %%
hw_idx
# Out:
#     Gene_type     Sex     ID Block  Error_Count
# 0          KO  Female  KOF_0  D1_1         10.0
# 1          KO  Female  KOF_0  D1_2          1.8
# 2          KO  Female  KOF_0  D2_1          1.2
# 3          KO  Female  KOF_0  D2_2          0.4
# 4          KO  Female  KOF_0  D3_1          0.2
# ..        ...     ...    ...   ...          ...
# 271        WT    Male  WTM_9  D1_2          1.8
# 272        WT    Male  WTM_9  D2_1          2.0
# 273        WT    Male  WTM_9  D2_2          1.0
# 274        WT    Male  WTM_9  D3_1          0.6
# 275        WT    Male  WTM_9  D3_2          0.0
#
# [276 rows x 5 columns]

# %%
HW_idx = {'Genotype':[], 'Group':[], 'Sex':[], 'ID':[], 'Enc_idx':[], 'Ret_idx':[]}

# %%
for sub in hw_idx['ID'].unique():
    HW_idx['ID'].append(sub)
    HW_idx['Genotype'].append(hw_idx['Gene_type'][hw_idx['ID']==sub].unique().item())
    HW_idx['Group'].append(sub.split('_')[0])
    HW_idx['Sex'].append(hw_idx['Sex'][hw_idx['ID']==sub].unique().item())
    
    temp_d1_1 = hw_idx['Error_Count'][(hw_idx['ID']==sub)&(hw_idx['Block']=='D1_1')].item()
    temp_d1_2 = hw_idx['Error_Count'][(hw_idx['ID']==sub)&(hw_idx['Block']=='D1_2')].item()
    temp_d2_1 = hw_idx['Error_Count'][(hw_idx['ID']==sub)&(hw_idx['Block']=='D2_1')].item()
    temp_d2_2 = hw_idx['Error_Count'][(hw_idx['ID']==sub)&(hw_idx['Block']=='D2_2')].item()
    temp_d3_1 = hw_idx['Error_Count'][(hw_idx['ID']==sub)&(hw_idx['Block']=='D3_1')].item()
    temp_d3_2 = hw_idx['Error_Count'][(hw_idx['ID']==sub)&(hw_idx['Block']=='D3_2')].item()
    
    try:
        temp_enc =  ((1-temp_d1_2/temp_d1_1)+(1-temp_d2_2/temp_d2_1))/2
        HW_idx['Enc_idx'].append(temp_enc)
    except ZeroDivisionError:
        HW_idx['Enc_idx'].append(0.0)
    try:
        temp_ret =  ((1-temp_d2_1/temp_d1_2)+(1-temp_d3_1/temp_d2_2))/2
        HW_idx['Ret_idx'].append(temp_ret)
    except ZeroDivisionError:
        HW_idx['Ret_idx'].append(0.0)

# %%
for key in HW_idx.keys():
    print(len(HW_idx[key]))
# Out:
# 46
# 46
# 46
# 46
# 46
# 46

# %%
K_df = pd.DataFrame(HW_idx)

# %%
pg.normality(K_df, dv='Enc_idx', group='Group', method='normaltest')
# Out:
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/scipy/stats/stats.py:1534: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/scipy/stats/stats.py:1534: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=10
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#              W      pval  normal
# KOF  16.208826  0.000302   False
# KOM   1.697494  0.427951    True
# WTF   3.178993  0.204028    True
# WTM   5.729847  0.056988    True

# %%
pg.homoscedasticity(K_df, dv='Enc_idx', group='Group')
# Out:
#                W      pval  equal_var
# levene  0.509222  0.678082       True

# %%
pg.anova(K_df, dv='Enc_idx', between=['Genotype', 'Sex'])
# Out:
#            Source         SS    DF        MS         F     p-unc       np2
# 0        Genotype   0.001743   1.0  0.001743  0.004462  0.947058  0.000106
# 1             Sex   0.370741   1.0  0.370741  0.949043  0.335541  0.022097
# 2  Genotype * Sex   0.018923   1.0  0.018923  0.048441  0.826865  0.001152
# 3        Residual  16.407200  42.0  0.390648       NaN       NaN       NaN

# %% [markdown]
# No hay diferencias en los indices; dividos por genotipo y sexo

# %%
sns.boxplot(data=K_df, x='Group', y='Enc_idx', showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['forestgreen', 'forestgreen', 'royalblue', 'royalblue'])

# %%
sns.boxplot(data=K_df, x='Group', y='Ret_idx', showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['forestgreen', 'forestgreen', 'royalblue', 'royalblue'])

# %%
pg.normality(data=hwk_class[hwk_class['Block']=='D1_1'], dv='Error_Count', group='Group')
# Out:
#             W          pval  normal
# KOF  0.793445  9.302531e-08   False
# KOM  0.769179  2.487877e-08   False
# WTF  0.681110  3.850563e-09   False
# WTM  0.731724  3.817973e-09   False

# %%
pg.normality(data=hwk_class[hwk_class['Block']=='D1_1'], dv='Error_Count', method='normaltest', group='Group')
# Out:
#              W          pval  normal
# KOF  21.862476  1.789055e-05   False
# KOM  20.969425  2.796065e-05   False
# WTF  48.076913  3.632712e-11   False
# WTM  40.457561  1.639654e-09   False

# %%
pg.kruskal(data=hwk_class[hwk_class['Block']=='D1_1'], dv='Error_Count', between='Group')
# Out:
#         Source  ddof1         H     p-unc
# Kruskal  Group      3  7.112254  0.068405

# %%
pg.anova(data=hwk_class[hwk_class['Block']=='D1_1'], dv='Error_Count', between=['Sex', 'Gene_type'])
# Out:
#             Source            SS     DF          MS         F     p-unc  \
# 0              Sex    233.475325    1.0  233.475325  3.919021  0.048956
# 1        Gene_type    411.648052    1.0  411.648052  6.909755  0.009161
# 2  Sex * Gene_type    255.612857    1.0  255.612857  4.290612  0.039459
# 3         Residual  13463.930000  226.0   59.574912       NaN       NaN
#
#         np2
# 0  0.017045
# 1  0.029667
# 2  0.018631
# 3       NaN

# %%
pg.pairwise_tukey(data=hwk_class[hwk_class['Block']=='D1_1'], dv='Error_Count', between='Group')
# Out:
#      A    B   mean(A)   mean(B)      diff        se       tail         T  \
# 0  KOF  KOM  9.916667  5.883333  4.033333  1.409195  two-sided  2.862154
# 1  KOF  WTF  9.916667  5.020000  4.896667  1.477976  two-sided  3.313089
# 2  KOF  WTM  9.916667  5.216667  4.700000  1.409195  two-sided  3.335238
# 3  KOM  WTF  5.883333  5.020000  0.863333  1.477976  two-sided  0.584132
# 4  KOM  WTM  5.883333  5.216667  0.666667  1.409195  two-sided  0.473083
# 5  WTF  WTM  5.020000  5.216667 -0.196667  1.477976  two-sided -0.133065
#
#     p-tukey    hedges
# 0  0.022343  0.519227
# 1  0.005285  0.629992
# 2  0.004896  0.605050
# 3  0.900000  0.111074
# 4  0.900000  0.085823
# 5  0.900000 -0.025303

# %%
sns.boxplot(data= hwk_class[hwk_class['Block']=='D1_1'], x='Group', y='Error Count', showmeans=True, meanprops={'marker':'+', 'markeredgecolor':'k'}, width=0.5, palette=['forestgreen', 'forestgreen', 'royalblue', 'royalblue'])

# %%
sns.lineplot(x='Block', y='Latency', hue='Gene_type', data=hwk_test, estimator='mean', ci=68, style='Sex', palette=['forestgreen', 'royalblue'], markers=['o', 'v', 'o', 'v'], err_style = 'bars', err_kws={'capsize':2, 'capthick':2})

# %%
lat_fig = plt.figure()
lat_ax= plt.subplot()
sns.lineplot(x='Block', y='Latency', hue='Gene_type', data=hwk_class, estimator='mean', ci=68, style='Sex', palette=['forestgreen', 'royalblue'], markers=['o', 'v', 'o', 'v'], err_style = 'bars', err_kws={'capsize':2, 'capthick':2})
lat_ax.set_ylabel('Latency (sec)')
lat_ax.legend(ncol=2, labels = ['KO Fem', 'KO Male', 'WT Fem', 'WT Male'])

# %%
lat_fig.savefig('/Users/labc02/Documents/PDCB_data/Behavior/Figures/lat_fig_all_groups.png', dpi=600)

# %%
pg.normality(data=hwk_class, dv='Latency', group='Group', method='normaltest')
# Out:
#               W          pval  normal
# KOF  292.618197  2.875848e-64   False
# KOM  323.487719  5.695533e-71   False
# WTF  337.859066  4.313560e-74   False
# WTM  355.048548  7.983392e-78   False

# %%
pg.homoscedasticity(data=hwk_class, dv='Latency', group='Group')
# Out:
#                W      pval  equal_var
# levene  7.014681  0.000111      False

# %%
pg.mixed_anova(data=hwk_class, dv='Latency', within='Block', subject='ID', between='Group')
# Out:
#         Source            SS  DF1  DF2           MS           F         p-unc  \
# 0        Group   1418.360745    3   42   472.786915    6.862229  7.257486e-04
# 1        Block  16062.907432    5  210  3212.581486  108.204010  3.928216e-56
# 2  Interaction   1229.948325   15  210    81.996555    2.761753  6.510822e-04
#
#       p-GG-corr       np2       eps sphericity   W-spher       p-spher
# 0           NaN  0.328931       NaN        NaN       NaN           NaN
# 1  5.124984e-28  0.720380  0.493943      False  0.068802  5.894487e-18
# 2           NaN  0.164765       NaN        NaN       NaN           NaN

# %%
pg.pairwise_ttests(data=hwk_class, dv='Latency', between='Group', within='Block', subject='ID', padjust='holm')
# Out:
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/pingouin/parametric.py:197: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to "
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/pingouin/effsize.py:689: UserWarning: x and y have unequal sizes. Switching to paired == False.
#   warnings.warn("x and y have unequal sizes. Switching to "
#          Contrast Block     A     B Paired  Parametric          T         dof  \
# 0           Block     -  D1_1  D1_2   True        True   6.022067  229.000000
# 1           Block     -  D1_1  D2_1   True        True   9.922559  229.000000
# 2           Block     -  D1_1  D2_2   True        True  11.401870  229.000000
# 3           Block     -  D1_1  D3_1   True        True  11.409083  229.000000
# 4           Block     -  D1_1  D3_2   True        True  12.319950  246.263879
# 5           Block     -  D1_2  D2_1   True        True   4.821706  229.000000
# 6           Block     -  D1_2  D2_2   True        True   6.146365  229.000000
# 7           Block     -  D1_2  D3_1   True        True   6.477893  229.000000
# 8           Block     -  D1_2  D3_2   True        True   7.908737  266.222312
# 9           Block     -  D2_1  D2_2   True        True   3.674231  229.000000
# 10          Block     -  D2_1  D3_1   True        True   3.358972  229.000000
# 11          Block     -  D2_1  D3_2   True        True   6.723512  403.764941
# 12          Block     -  D2_2  D3_1   True        True   0.237977  229.000000
# 13          Block     -  D2_2  D3_2   True        True   3.669995  438.922082
# 14          Block     -  D3_1  D3_2   True        True   3.005897  401.635721
# 15          Group     -   KOF   KOM  False        True   2.316063   22.000000
# 16          Group     -   KOF   WTF  False        True   3.968789   18.173648
# 17          Group     -   KOF   WTM  False        True   4.591879   22.000000
# 18          Group     -   KOM   WTF  False        True   0.802346   16.528287
# 19          Group     -   KOM   WTM  False        True   1.221354   22.000000
# 20          Group     -   WTF   WTM  False        True   0.616148   18.757265
# 21  Block * Group  D1_1   KOF   KOM  False        True   2.273057  118.000000
# 22  Block * Group  D1_1   KOF   WTF  False        True   2.473234  102.309049
# 23  Block * Group  D1_1   KOF   WTM  False        True   2.746590  118.000000
# 24  Block * Group  D1_1   KOM   WTF  False        True   0.441156   99.499149
# 25  Block * Group  D1_1   KOM   WTM  False        True   0.664041  118.000000
# 26  Block * Group  D1_1   WTF   WTM  False        True   0.152801   99.377113
# 27  Block * Group  D1_2   KOF   KOM  False        True   0.748256  118.000000
# 28  Block * Group  D1_2   KOF   WTF  False        True   2.461673   72.511447
# 29  Block * Group  D1_2   KOF   WTM  False        True   2.266775  118.000000
# 30  Block * Group  D1_2   KOM   WTF  False        True   1.633457   75.115845
# 31  Block * Group  D1_2   KOM   WTM  False        True   1.441261  118.000000
# 32  Block * Group  D1_2   WTF   WTM  False        True  -0.268184  106.845299
# 33  Block * Group  D2_1   KOF   KOM  False        True  -0.353630  118.000000
# 34  Block * Group  D2_1   KOF   WTF  False        True   0.480683  102.094311
# 35  Block * Group  D2_1   KOF   WTM  False        True   2.433780  118.000000
# 36  Block * Group  D2_1   KOM   WTF  False        True   0.709284  102.873775
# 37  Block * Group  D2_1   KOM   WTM  False        True   2.097938  118.000000
# 38  Block * Group  D2_1   WTF   WTM  False        True   1.675473   87.096863
# 39  Block * Group  D2_2   KOF   KOM  False        True   0.529180  118.000000
# 40  Block * Group  D2_2   KOF   WTF  False        True   1.792681   98.257305
# 41  Block * Group  D2_2   KOF   WTM  False        True   1.018289  118.000000
# 42  Block * Group  D2_2   KOM   WTF  False        True   1.005181   91.344207
# 43  Block * Group  D2_2   KOM   WTM  False        True   0.352825  118.000000
# 44  Block * Group  D2_2   WTF   WTM  False        True  -0.812733  106.727138
# 45  Block * Group  D3_1   KOF   KOM  False        True   2.922207  118.000000
# 46  Block * Group  D3_1   KOF   WTF  False        True   1.790132  107.727201
# 47  Block * Group  D3_1   KOF   WTM  False        True   4.246077  118.000000
# 48  Block * Group  D3_1   KOM   WTF  False        True  -0.754705   77.415182
# 49  Block * Group  D3_1   KOM   WTM  False        True   1.823909  118.000000
# 50  Block * Group  D3_1   WTF   WTM  False        True   1.905710   54.735346
# 51  Block * Group  D3_2   KOF   KOM  False        True   3.346378   62.692314
# 52  Block * Group  D3_2   KOF   WTF  False        True   2.296229   82.069250
# 53  Block * Group  D3_2   KOF   WTM  False        True   1.890584   81.956903
# 54  Block * Group  D3_2   KOM   WTF  False        True  -1.694946   66.478094
# 55  Block * Group  D3_2   KOM   WTM  False        True  -2.626425  118.000000
# 56  Block * Group  D3_2   WTF   WTM  False        True  -0.688180  106.629179
#
#          Tail         p-unc        p-corr p-adjust       BF10    hedges
# 0   two-sided  6.795740e-09  4.757018e-08     holm  1.243e+06  0.536261
# 1   two-sided  1.563886e-19  1.876663e-18     holm  2.926e+16  0.916051
# 2   two-sided  3.813761e-24  5.064341e-23     holm  1.001e+21  1.033928
# 3   two-sided  3.617386e-24  5.064341e-23     holm  1.054e+21  1.029510
# 4   two-sided  1.719783e-27  2.579675e-26     holm   9.68e+26  1.145883
# 5   two-sided  2.594787e-06  1.556872e-05     holm   4165.545  0.413081
# 6   two-sided  3.485703e-09  2.788563e-08     holm  2.366e+06  0.576089
# 7   two-sided  5.620824e-10  5.058741e-09     holm   1.38e+07  0.573474
# 8   two-sided  6.969445e-14  7.666389e-13     holm  2.909e+11  0.735720
# 9   two-sided  2.971053e-04  1.361971e-03     holm     48.093  0.297213
# 10  two-sided  9.162329e-04  2.748699e-03     holm     17.008  0.293250
# 11  two-sided  6.073251e-11  6.073251e-10     holm  1.427e+08  0.626122
# 12  two-sided  8.121114e-01  8.121114e-01     holm      0.076  0.021802
# 13  two-sided  2.723943e-04  1.361971e-03     holm     65.774  0.341885
# 14  two-sided  2.814186e-03  5.628372e-03     holm        8.0  0.279917
# 15  two-sided  3.026178e-02  1.210471e-01     holm       2.33  0.912924
# 16  two-sided  8.859013e-04  4.429507e-03     holm     37.746  1.560520
# 17  two-sided  1.421355e-04  8.528129e-04     holm    151.206  1.809984
# 18  two-sided  4.337385e-01  8.674769e-01     holm      0.486  0.311661
# 19  two-sided  2.348794e-01  7.046381e-01     holm      0.638  0.481422
# 20  two-sided  5.452026e-01  8.674769e-01     holm      0.442  0.255408
# 21  two-sided  2.483201e-02  6.779536e-01     holm      1.951  0.412358
# 22  two-sided  1.503656e-02  4.661333e-01     holm      3.013  0.453083
# 23  two-sided  6.966171e-03  2.298836e-01     holm      5.515  0.498262
# 24  two-sided  6.600568e-01  1.000000e+00     holm      0.221  0.084734
# 25  two-sided  5.079594e-01  1.000000e+00     holm      0.237  0.120465
# 26  two-sided  8.788648e-01  1.000000e+00     holm      0.205  0.029355
# 27  two-sided  4.557945e-01  1.000000e+00     holm       0.25  0.135742
# 28  two-sided  1.620790e-02  4.862370e-01     holm       2.94  0.434082
# 29  two-sided  2.522534e-02  6.779536e-01     holm      1.927  0.411219
# 30  two-sided  1.065579e-01  1.000000e+00     holm      0.666  0.288907
# 31  two-sided  1.521594e-01  1.000000e+00     holm      0.495  0.261461
# 32  two-sided  7.890748e-01  1.000000e+00     holm       0.21 -0.049693
# 33  two-sided  7.242470e-01  1.000000e+00     holm      0.206 -0.064153
# 34  two-sided  6.317704e-01  1.000000e+00     holm      0.225  0.091880
# 35  two-sided  1.644106e-02  4.862370e-01     holm       2.72  0.441515
# 36  two-sided  4.797526e-01  1.000000e+00     holm      0.254  0.130077
# 37  two-sided  3.804453e-02  9.511134e-01     holm      1.392  0.380590
# 38  two-sided  9.742816e-02  1.000000e+00     holm      0.708  0.327962
# 39  two-sided  5.976747e-01  1.000000e+00     holm      0.221  0.095999
# 40  two-sided  7.610121e-02  1.000000e+00     holm      0.847  0.326212
# 41  two-sided  3.106237e-01  1.000000e+00     holm       0.31  0.184729
# 42  two-sided  3.174651e-01  1.000000e+00     holm      0.319  0.181206
# 43  two-sided  7.248488e-01  1.000000e+00     holm      0.206  0.064007
# 44  two-sided  4.181802e-01  1.000000e+00     holm      0.273 -0.150527
# 45  two-sided  4.166485e-03  1.416605e-01     holm      8.487  0.530121
# 46  two-sided  7.624196e-02  1.000000e+00     holm      0.844  0.336273
# 47  two-sided  4.360376e-05  1.569735e-03     holm    456.441  0.770286
# 48  two-sided  4.527160e-01  1.000000e+00     holm      0.262 -0.149769
# 49  two-sided  7.069640e-02  1.000000e+00     holm      0.864  0.330878
# 50  two-sided  6.194519e-02  1.000000e+00     holm      1.018  0.392542
# 51  two-sided  1.387356e-03  4.855748e-02     holm     26.497  0.614381
# 52  two-sided  2.421263e-02  6.779536e-01     holm      2.092  0.414113
# 53  two-sided  6.221393e-02  1.000000e+00     holm      0.967  0.346279
# 54  two-sided  9.476553e-02  1.000000e+00     holm      0.729 -0.341953
# 55  two-sided  9.773084e-03  3.127387e-01     holm      4.164 -0.476463
# 56  two-sided  4.928336e-01  1.000000e+00     holm      0.251 -0.130013

# %%
lat_fig2 = plt.figure()
lat_2 = plt.subplot()
sns.lineplot(x='Block', y='Latency', hue='Gene_type', data=hwk_class, estimator='mean', ci=68, style='Gene_type', palette=['forestgreen', 'royalblue'], markers=['o', 'o'], dashes=False, err_style = 'bars', err_kws={'capsize':2, 'capthick':2}, ax= lat_2)
lat_2.annotate('*', xy=(76, 125), xytext=(76, 125), xycoords='axes points', ha='center',
                va='bottom', arrowprops=dict(arrowstyle='-[, widthB=0.5, lengthB=.1', lw=1, color='k'))
lat_2.legend(labels=('KO', 'WT'))

# %%
lat_fig2.savefig('/Users/labc02/Documents/PDCB_data/Behavior/Figures/lat_fig_two_groups.png', dpi=600)

# %%
pg.normality(data=hwk_class, dv='Latency', group='Gene_type', method='normaltest')
# Out:
#              W           pval  normal
# KO  598.631803  1.020365e-130   False
# WT  660.566464  3.629233e-144   False

# %%
pg.mixed_anova(data=hwk_class, dv='Latency', within='Block', subject='ID', between='Gene_type')
# Out:
#         Source            SS  DF1  DF2           MS           F         p-unc  \
# 0    Gene_type    844.342424    1   44   844.342424   10.713486  2.074808e-03
# 1        Block  16062.907432    5  220  3212.581486  102.480327  1.818408e-55
# 2  Interaction    568.236416    5  220   113.647283    3.625312  3.587661e-03
#
#       p-GG-corr       np2       eps sphericity   W-spher       p-spher
# 0           NaN  0.195811       NaN        NaN       NaN           NaN
# 1  5.124984e-28  0.699618  0.493943      False  0.068802  5.894487e-18
# 2           NaN  0.076122       NaN        NaN       NaN           NaN

# %%
pg.pairwise_ttests(data=hwk_class, dv='Latency', between='Gene_type', within='Block', subject='ID', padjust='holm')
# Out:
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/pingouin/parametric.py:197: UserWarning: x and y have unequal sizes. Switching to paired == False. Check your data.
#   warnings.warn("x and y have unequal sizes. Switching to "
# /opt/miniconda3/envs/databs/lib/python3.8/site-packages/pingouin/effsize.py:689: UserWarning: x and y have unequal sizes. Switching to paired == False.
#   warnings.warn("x and y have unequal sizes. Switching to "
#              Contrast Block     A     B Paired  Parametric          T  \
# 0               Block     -  D1_1  D1_2   True        True   6.022067
# 1               Block     -  D1_1  D2_1   True        True   9.922559
# 2               Block     -  D1_1  D2_2   True        True  11.401870
# 3               Block     -  D1_1  D3_1   True        True  11.409083
# 4               Block     -  D1_1  D3_2   True        True  12.319950
# 5               Block     -  D1_2  D2_1   True        True   4.821706
# 6               Block     -  D1_2  D2_2   True        True   6.146365
# 7               Block     -  D1_2  D3_1   True        True   6.477893
# 8               Block     -  D1_2  D3_2   True        True   7.908737
# 9               Block     -  D2_1  D2_2   True        True   3.674231
# 10              Block     -  D2_1  D3_1   True        True   3.358972
# 11              Block     -  D2_1  D3_2   True        True   6.723512
# 12              Block     -  D2_2  D3_1   True        True   0.237977
# 13              Block     -  D2_2  D3_2   True        True   3.669995
# 14              Block     -  D3_1  D3_2   True        True   3.005897
# 15          Gene_type     -    KO    WT  False        True   3.366894
# 16  Block * Gene_type  D1_1    KO    WT  False        True   2.424370
# 17  Block * Gene_type  D1_2    KO    WT  False        True   2.766499
# 18  Block * Gene_type  D2_1    KO    WT  False        True   2.015155
# 19  Block * Gene_type  D2_2    KO    WT  False        True   1.383020
# 20  Block * Gene_type  D3_1    KO    WT  False        True   2.492814
# 21  Block * Gene_type  D3_2    KO    WT  False        True   0.915756
#
#            dof       Tail         p-unc        p-corr p-adjust       BF10  \
# 0   229.000000  two-sided  6.795740e-09  4.757018e-08     holm  1.243e+06
# 1   229.000000  two-sided  1.563886e-19  1.876663e-18     holm  2.926e+16
# 2   229.000000  two-sided  3.813761e-24  5.064341e-23     holm  1.001e+21
# 3   229.000000  two-sided  3.617386e-24  5.064341e-23     holm  1.054e+21
# 4   246.263879  two-sided  1.719783e-27  2.579675e-26     holm   9.68e+26
# 5   229.000000  two-sided  2.594787e-06  1.556872e-05     holm   4165.545
# 6   229.000000  two-sided  3.485703e-09  2.788563e-08     holm  2.366e+06
# 7   229.000000  two-sided  5.620824e-10  5.058741e-09     holm   1.38e+07
# 8   266.222312  two-sided  6.969445e-14  7.666389e-13     holm  2.909e+11
# 9   229.000000  two-sided  2.971053e-04  1.361971e-03     holm     48.093
# 10  229.000000  two-sided  9.162329e-04  2.748699e-03     holm     17.008
# 11  403.764941  two-sided  6.073251e-11  6.073251e-10     holm  1.427e+08
# 12  229.000000  two-sided  8.121114e-01  8.121114e-01     holm      0.076
# 13  438.922082  two-sided  2.723943e-04  1.361971e-03     holm     65.774
# 14  401.635721  two-sided  2.814186e-03  5.628372e-03     holm        8.0
# 15   33.013523  two-sided  1.943407e-03           NaN      NaN     21.301
# 16  217.741917  two-sided  1.615094e-02  6.705217e-02     holm      2.255
# 17  157.165228  two-sided  6.345913e-03  3.807548e-02     holm      5.122
# 18  211.965824  two-sided  4.515131e-02  1.354539e-01     holm      0.969
# 19  207.828364  two-sided  1.681427e-01  3.362853e-01     holm      0.355
# 20  220.100598  two-sided  1.341043e-02  6.705217e-02     holm      2.635
# 21  196.423758  two-sided  3.609180e-01  3.609180e-01     holm      0.215
#
#       hedges
# 0   0.536261
# 1   0.916051
# 2   1.033928
# 3   1.029510
# 4   1.145883
# 5   0.413081
# 6   0.576089
# 7   0.573474
# 8   0.735720
# 9   0.297213
# 10  0.293250
# 11  0.626122
# 12  0.021802
# 13  0.341885
# 14  0.279917
# 15  0.949026
# 16  0.314803
# 17  0.352475
# 18  0.261023
# 19  0.178866
# 20  0.324072
# 21  0.118526

# %%
fx, axs = plt.subplots(ncols=1, nrows=2, sharex=True)
sns.regplot(data=hwk_class[hwk_class['Gene_type']=='WT'], x='Latency', y='Error_Count', ax=axs[0], color='royalblue')
sns.regplot(data=hwk_class[hwk_class['Gene_type']=='KO'], x='Latency', y='Error_Count', ax=axs[1], color='forestgreen')
axs[0].set_xlabel('')
axs[1].set_xlabel('Latency (sec)')
axs[0].set_ylabel('Mean Error Count')
axs[1].set_ylabel('Mean Error Count')
plt.tight_layout()

# %%
fx.savefig('/Users/labc02/Documents/PDCB_data/Behavior/Figures/err_lat_corr.png', dpi=600)

# %% [markdown]
# ## Other versions of the figures

# %%
err_lat = plt.figure(figsize=(7.3, 5))
err_ax = plt.subplot(211)
sns.lineplot(x='Block', y='Error_Count', hue='Gene_type', data=hwk_class, estimator='mean', ci=68, style='Sex', palette=['forestgreen', 'royalblue'], markers=['o', 'v', 'o', 'v'], err_style = 'bars', err_kws={'capsize':2, 'capthick':2}, ax = err_ax)
err_ax.set_ylabel('Mean Error Count')
err_ax.legend(ncol=2, labels=['KO Fem', 'KO Male', 'WT Fem','WT Male'])
err_ax.set_ylim(0,13)
err_ax.annotate('*', xy=(22, 117), xytext=(22, 117), xycoords='axes points', ha='center',
                va='bottom', arrowprops=dict(arrowstyle='-[, widthB=0.5, lengthB=.1', lw=1, color='k'))
lat_ax= plt.subplot(212)
sns.lineplot(x='Block', y='Latency', hue='Gene_type', data=hwk_class, estimator='mean', ci=68, style='Sex', palette=['forestgreen', 'royalblue'], markers=['o', 'v', 'o', 'v'], err_style = 'bars', err_kws={'capsize':2, 'capthick':2}, ax = lat_ax, legend=False)
lat_ax.set_ylabel('Latency (sec)')
plt.tight_layout()

# %%
err_lat.savefig('/Users/labc02/Documents/PDCB_data/Behavior/Figures/err_lat_fig_all_groups.png', dpi=600)

# %%
err_lat2 = plt.figure(figsize=(6, 3))
err_ax2 = plt.subplot(211)
sns.lineplot(x='Block', y='Error_Count', hue='Gene_type', data=hwk_class, estimator='mean', ci=68, palette=['forestgreen', 'royalblue'], style='Gene_type', dashes=False, markers=['o', 'o'], err_style = 'bars', err_kws={'capsize':2, 'capthick':2}, ax = err_ax2)
sns.despine()
err_ax2.set_ylim(0, 10)
err_ax2.annotate('*', xy=(16, 58), xytext=(16, 58), xycoords='axes points', ha='center',
                va='bottom', arrowprops=dict(arrowstyle='-[, widthB=0.5, lengthB=.1', lw=1, color='k'))
err_ax2.legend(ncol=2, labels=['KO', 'WT'])
err_ax2.set_ylabel('Mean Error Count')
err_ax2.set_xlabel('')
lat_2 = plt.subplot(212)
sns.lineplot(x='Block', y='Latency', hue='Gene_type', data=hwk_class, estimator='mean', ci=68, style='Gene_type', palette=['forestgreen', 'royalblue'], markers=['o', 'o'], dashes=False, err_style = 'bars', err_kws={'capsize':2, 'capthick':2}, ax= lat_2, legend=False)
sns.despine()
lat_2.annotate('*', xy=(85, 36), xytext=(85, 36), xycoords='axes points', ha='center',
                va='bottom', arrowprops=dict(arrowstyle='-[, widthB=0.5, lengthB=.1', lw=1, color='k'))
plt.tight_layout()

# %%
err_lat2.savefig('/Users/labc02/Documents/PDCB_data/Behavior/Figures/err_lat_fig_paper.svg')
